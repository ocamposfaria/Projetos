# %% [markdown]
# ## Imports

# %%
from pulp import *
import googlemaps
import pandas as pd

# %%
#googlemaps.Client(key = 'AIzaSyBU3xNODle9W35YxeAhWsX4P6C0fsxcopY')

# %%
df_unidades = pd.read_csv('unidades de saude new new.csv', delimiter = ';', encoding='utf-8')
df_centros = pd.read_csv('centros de distribuicao new.csv', delimiter = ';', decimal=',')

df = pd.read_csv('utf8.csv', encoding='utf-8', delimiter=';')
df = df.drop(columns=['Column1'])

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_ccc83_ thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_ccc83_ tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_ccc83_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Column2</th>
#       <th class="col_heading level0 col1" >Hospital Regional da Asa Norte</th>
#       <th class="col_heading level0 col2" >Hospital Regional da Ceilândia</th>
#       <th class="col_heading level0 col3" >Hospital Regional do Gama</th>
#       <th class="col_heading level0 col4" >Hospital Regional do Paranoá</th>
#       <th class="col_heading level0 col5" >Hospital Regional de Planaltina</th>
#       <th class="col_heading level0 col6" >Hospital Regional de Taguatinga</th>
# ...

# %%
unidades = df['Column2'].to_list()
df = df.set_index('Column2')

CDs = df.columns.to_list()
df = df.to_dict()

# %%
oferta = df_centros[['CENTRAL REGIONAL', 'OFERTA']].set_index('CENTRAL REGIONAL').to_dict()['OFERTA']

# %%
oferta
# Out:
# {'Hospital Regional da Asa Norte': 100000,
#  'Hospital Regional da Ceilândia': 100000,
#  'Hospital Regional do Gama': 100000,
#  'Hospital Regional do Paranoá': 100000,
#  'Hospital Regional de Planaltina': 100000,
#  'Hospital Regional de Taguatinga': 100000,
#  'Hospital Regional de Sobradinho': 100000,
#  'UBS 1 - Núcleo Bandeirante': 100000}

# %%
demanda = df_unidades[['Ponto de Aplicação', 'Demanda']].set_index('Ponto de Aplicação').to_dict()['Demanda']

# %%
demanda
# Out:
# {'Unidade Básica de Saúde 1 Águas Claras': 2000,
#  'UBS 2 - Areal': 2000,
#  'SAP 01 da Asa Norte': 2000,
#  'Unidade Básica de Saúde (UBS) 2 Asa Norte': 2000,
#  'Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto': 2000,
#  'Posto de Saúde- Granja do Torto': 2000,
#  'Unidade Básica de Saúde 1 Asa Sul': 2000,
#  'Centro de Saúde N° 1 de Brazlândia': 2000,
#  'UBS 2 Brazlândia': 2000,
#  'UBS 3 Brazlândia - Veredas I': 2000,
#  'UBS 4 Brazlândia - Veredas II': 2000,
#  'UBS 5 Brazlândia - Chapadinha': 2000,
#  'Unidade Básica de Saúde (UBS) 6 Brazlândia': 2000,
#  'UBS 8 Brazlândia - Torre de Brazlândia': 2000,
#  'UBS 01 - Candangolândia': 2000,
#  'UBS 01 de Ceilândia': 2000,
#  'UBS 02 de Ceilândia': 2000,
#  'UBS 03 de Ceilândia': 2000,
#  'UBS 05 de Ceilândia': 2000,
#  'Unidade Básica de Saúde (UBS) 6 Ceilândia': 2000,
#  'UBS 7 de Ceilândia': 2000,
#  'Unidade Básica de Saúde (UBS) 8 Ceilândia': 2000,
#  'Unidade Básica de Saúde (UBS) 9 Ceilândia': 2000,
# ...

# %% [markdown]
# ## Modeling

# %%
prob = LpProblem("THE_P_MEDIAN_PROBLEM", LpMinimize)

# %%
p = 8

# %%
CDs
# Out:
# ['Hospital Regional da Asa Norte',
#  'Hospital Regional da Ceilândia',
#  'Hospital Regional do Gama',
#  'Hospital Regional do Paranoá',
#  'Hospital Regional de Planaltina',
#  'Hospital Regional de Taguatinga',
#  'Hospital Regional de Sobradinho',
#  'UBS 1 - Núcleo Bandeirante']

# %%
x = LpVariable.dicts('X_%s_to_%s', (CDs,unidades), 
    cat = 'Binary', 
    lowBound = 0, 
    upBound = 1)

# %%
y = LpVariable.dicts('Y_%s', (CDs),
    cat = 'Binary', 
    lowBound = 0, 
    upBound = 1)

# %%
prob += sum(x[i][j]*df[i][j] for i in CDs for j in unidades), "Distância total entre CDs e unidades"

# %%
df
# Out:
# {'Hospital Regional da Asa Norte': {'Unidade Básica de Saúde 1 Águas Claras': 24596,
#   'UBS 2 - Areal': 24914,
#   'SAP 01 da Asa Norte': 2471,
#   'Unidade Básica de Saúde (UBS) 2 Asa Norte': 6566,
#   'Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto': 8591,
#   'Posto de Saúde- Granja do Torto': 11556,
#   'Unidade Básica de Saúde 1 Asa Sul': 8997,
#   'Centro de Saúde N° 1 de Brazlândia': 48909,
#   'UBS 2 Brazlândia': 48440,
#   'UBS 3 Brazlândia - Veredas I': 48925,
#   'UBS 4 Brazlândia - Veredas II': 48645,
#   'UBS 5 Brazlândia - Chapadinha': 43663,
#   'Unidade Básica de Saúde (UBS) 6 Brazlândia': 69180,
#   'UBS 8 Brazlândia - Torre de Brazlândia': 45879,
#   'UBS 01 - Candangolândia': 14712,
#   'UBS 01 de Ceilândia': 32625,
#   'UBS 02 de Ceilândia': 30686,
#   'UBS 03 de Ceilândia': 27123,
#   'UBS 05 de Ceilândia': 29724,
#   'Unidade Básica de Saúde (UBS) 6 Ceilândia': 29493,
#   'UBS 7 de Ceilândia': 32720,
# ...

# %%
x
# Out:
# {'Hospital Regional da Asa Norte': {'Unidade Básica de Saúde 1 Águas Claras': X_Hospital_Regional_da_Asa_Norte_to_Unidade_Básica_de_Saúde_1_Águas_Claras,
#   'UBS 2 - Areal': X_Hospital_Regional_da_Asa_Norte_to_UBS_2___Areal,
#   'SAP 01 da Asa Norte': X_Hospital_Regional_da_Asa_Norte_to_SAP_01_da_Asa_Norte,
#   'Unidade Básica de Saúde (UBS) 2 Asa Norte': X_Hospital_Regional_da_Asa_Norte_to_Unidade_Básica_de_Saúde_(UBS)_2_Asa_Norte,
#   'Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto': X_Hospital_Regional_da_Asa_Norte_to_Unidade_Básica_de_Saúde_(UBS)_3___Asa_Norte___Vila_Planalto,
#   'Posto de Saúde- Granja do Torto': X_Hospital_Regional_da_Asa_Norte_to_Posto_de_Saúde__Granja_do_Torto,
#   'Unidade Básica de Saúde 1 Asa Sul': X_Hospital_Regional_da_Asa_Norte_to_Unidade_Básica_de_Saúde_1_Asa_Sul,
#   'Centro de Saúde N° 1 de Brazlândia': X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Saúde_N°_1_de_Brazlândia,
# ...

# %% [markdown]
# #### Constraints

# %%
# cada unidade deve receber vacinas de um, e apenas um, CD
for j in unidades:
        prob += sum(x[i][j] for i in CDs) == 1

# %%
# a quantodade de CDs abertos é igual a p
prob += lpSum(y[j] for j in CDs) == p

# %%
# apenas CDs abertos podem entregar vacinas
for i in CDs:
    for  j in unidades:
        prob += x[i][j]<= y[i]

# %%
# cada CD só pode atender no máximo x unidades
for i in CDs:
    prob += lpSum(x[i][j] for j in unidades) <= 100

# %%
# a soma das demandas das unidades para as quais determinado CD irá fazer entregas é menor que (ou igual) à oferta do CD
for i in CDs:
        prob += lpSum(demanda[j]*x[i][j] for j in unidades) <= oferta[i]*y[i]

# %%
oferta
# Out:
# {'Hospital Regional da Asa Norte': 100000,
#  'Hospital Regional da Ceilândia': 100000,
#  'Hospital Regional do Gama': 100000,
#  'Hospital Regional do Paranoá': 100000,
#  'Hospital Regional de Planaltina': 100000,
#  'Hospital Regional de Taguatinga': 100000,
#  'Hospital Regional de Sobradinho': 100000,
#  'UBS 1 - Núcleo Bandeirante': 100000}

# %% [markdown]
# ## Solving

# %%
prob.solve()
# Out:
# 1

# %%
print(f'Total: {prob.objective.value()/1000} Km')
# Out:
# Total: 2056.177 Km

# %%
for v in prob.variables():
    print(v.name , '=', v.varValue)
    #if v.varValue == 1:
        #print(v.name , '=', v.varValue)
# Out:
# X_Hospital_Regional_da_Asa_Norte_to_Associação_Comunitária_dos_Moradores_da_Vila_Basevi = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Associação_Médica_de_Brasília_(Ambr) = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_Cef_Jardim_Ii___Paranoá = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_De_Saude_N°_1___UBS_1_de_Vicente_Pires = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_Olímpico_Estrutural = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_Olímpico_de_Planaltina = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Progressão_Penitenciária = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Saúde_01_de_São_Sebastião = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Saúde_12_de_Ceilândia = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Saúde_3_Planaltina_FHDF = 0.0
# X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Saúde_3___Taguatinga = 0.0
# ...

# %%
df = pd.DataFrame(columns=['origem', 'destino'])
for v in prob.variables():
    #print(v.name , '=', v.varValue)
    if v.varValue == 1:
        #print(v.name , '=', v.varValue)
        split = v.name.split('_to_')
        split[0] = split[0].replace('X_', '')
        try:
            df = df.append({'origem': split[0], 'destino': split[1]}, ignore_index=True)
        except:
            pass

# %% [markdown]
# ## Result

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_683cb_ thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_683cb_ tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_683cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >origem</th>
#       <th class="col_heading level0 col1" >destino</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_683cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_683cb_row0_col0" class="data row0 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_683cb_row0_col1" class="data row0 col1" >Associação_Médica_de_Brasília_(Ambr)</td>
#     </tr>
#     <tr>
#       <th id="T_683cb_level0_row1" class="row_heading level0 row1" >1</th>
# ...

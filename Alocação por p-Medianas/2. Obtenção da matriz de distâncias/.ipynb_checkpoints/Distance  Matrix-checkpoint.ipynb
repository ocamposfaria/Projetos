# %% [markdown]
# ## Import libraries, get API client and data

# %%
import googlemaps
import pandas as pd

# %%
with open(r'..\..\..\Google API key.txt') as f:
    secret = f.readlines()[0]
client = googlemaps.Client(key = secret)

# %%
unidades = pd.read_csv(r'..\1. Obtenção de coordenadas geográficas\Lista Final com coordenadas.csv', delimiter=';')
unidades = unidades.drop(columns=['Unnamed: 0'])

# %%
unidades.style.set_sticky()
# Out:
# <style type="text/css">
# #T_61af7 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_61af7 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_61af7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61af7_level0_col0" class="col_heading level0 col0" >UBS</th>
#       <th id="T_61af7_level0_col1" class="col_heading level0 col1" >ENDEREÇO</th>
#       <th id="T_61af7_level0_col2" class="col_heading level0 col2" >REGIONAL DE SAÚDE</th>
#       <th id="T_61af7_level0_col3" class="col_heading level0 col3" >coordinates</th>
#       <th id="T_61af7_level0_col4" class="col_heading level0 col4" >google maps name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61af7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61af7_row0_col0" class="data row0 col0" >UBS 1 ASA SUL</td>
#       <td id="T_61af7_row0_col1" class="data row0 col1" >UBS 1 ASA SUL (CSB08), SGAS QUADRA 612 LOTES S/N, ASA SUL, Brasília-DF, 70200-720</td>
#       <td id="T_61af7_row0_col2" class="data row0 col2" >Região Central</td>
#       <td id="T_61af7_row0_col3" class="data row0 col3" >(-15.8326601, -47.909503)</td>
#       <td id="T_61af7_row0_col4" class="data row0 col4" >Unidade Básica de Saúde 1 Asa Sul</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61af7_row1_col0" class="data row1 col0" >UBS 1 CRUZEIRO</td>
#       <td id="T_61af7_row1_col1" class="data row1 col1" >UBS 1 CRUZEIRO (CSB09), Shces Quadra, 611 - Cruzeiro Novo, Brasília - DF, 70070-710</td>
#       <td id="T_61af7_row1_col2" class="data row1 col2" >Região Central</td>
#       <td id="T_61af7_row1_col3" class="data row1 col3" >(-15.800795, -47.942134)</td>
#       <td id="T_61af7_row1_col4" class="data row1 col4" >UBS 01 Cruzeiro Novo (GSAP)</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61af7_row2_col0" class="data row2 col0" >UBS 1 LAGO NORTE</td>
#       <td id="T_61af7_row2_col1" class="data row2 col1" >UBS 1 LAGO NORTE (CSB10), SHIN QI 3 03, LAGO NORTE, Brasília-DF, 71505-600</td>
#       <td id="T_61af7_row2_col2" class="data row2 col2" >Região Central</td>
#       <td id="T_61af7_row2_col3" class="data row2 col3" >(-15.7257082, -47.8739439)</td>
#       <td id="T_61af7_row2_col4" class="data row2 col4" >Vacinação COVID-19 - UBS 1 Lago Norte (Centro de Saúde n°10)</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61af7_row3_col0" class="data row3 col0" >UBS 1 ASA NORTE</td>
#       <td id="T_61af7_row3_col1" class="data row3 col1" >UBS 1 ASA NORTE (CSB11), SGAN 905, ASA NORTE, Brasília-DF, 70790-054</td>
#       <td id="T_61af7_row3_col2" class="data row3 col2" >Região Central</td>
#       <td id="T_61af7_row3_col3" class="data row3 col3" >(-15.7732459, -47.89242780000001)</td>
#       <td id="T_61af7_row3_col4" class="data row3 col4" >SAP 01 da Asa Norte</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61af7_row4_col0" class="data row4 col0" >UBS 2 ASA NORTE</td>
#       <td id="T_61af7_row4_col1" class="data row4 col1" >UBS 2 ASA NORTE (CSB13), Eqn 208 408, 208 - Asa Norte, Brasília - DF, 70853-450</td>
#       <td id="T_61af7_row4_col2" class="data row4 col2" >Região Central</td>
#       <td id="T_61af7_row4_col3" class="data row4 col3" >(-15.7616704, -47.8805846)</td>
#       <td id="T_61af7_row4_col4" class="data row4 col4" >CEDOH</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_61af7_row5_col0" class="data row5 col0" >UBS 3 ASA NORTE</td>
#       <td id="T_61af7_row5_col1" class="data row5 col1" >UBS 3 ASA NORTE, Rua Piau Acampamento Pacheco Fernandes, Área Especial, Vila Planalto, 2, Brasília - DF, 70804-190</td>
#       <td id="T_61af7_row5_col2" class="data row5 col2" >Região Central</td>
#       <td id="T_61af7_row5_col3" class="data row5 col3" >(-15.7951717, -47.8481369)</td>
#       <td id="T_61af7_row5_col4" class="data row5 col4" >Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_61af7_row6_col0" class="data row6 col0" >UBS 5 ASA NORTE</td>
#       <td id="T_61af7_row6_col1" class="data row6 col1" >UBS 5 ASA NORTE, Vila Weslian Roriz , Área Especial, 1, Granja do Torto, Lago Norte, Brasília - DF, 70636-003</td>
#       <td id="T_61af7_row6_col2" class="data row6 col2" >Região Central</td>
#       <td id="T_61af7_row6_col3" class="data row6 col3" >(-15.705292, -47.9059388)</td>
#       <td id="T_61af7_row6_col4" class="data row6 col4" >Residência Oficial da Granja do Torto</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_61af7_row7_col0" class="data row7 col0" >UBS 2 CRUZEIRO</td>
#       <td id="T_61af7_row7_col1" class="data row7 col1" >UBS 2 CRUZEIRO (CSB14), Shce Setor Escolar Lote, 4 - Cruzeiro Velho, Brasília - DF, 70070-710</td>
#       <td id="T_61af7_row7_col2" class="data row7 col2" >Região Central</td>
#       <td id="T_61af7_row7_col3" class="data row7 col3" >(-15.7835664, -47.9359858)</td>
#       <td id="T_61af7_row7_col4" class="data row7 col4" >Unidade Básica de Saúde (UBS) 2 Cruzeiro</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_61af7_row8_col0" class="data row8 col0" >UBS 1 VARJÃO</td>
#       <td id="T_61af7_row8_col1" class="data row8 col1" >UBS 1 VARJÃO (CSB16), VILA VARJAO QUADRA 5 05, VILA VARJAO DO TORTO, Brasília-DF, 71555-133</td>
#       <td id="T_61af7_row8_col2" class="data row8 col2" >Região Central</td>
#       <td id="T_61af7_row8_col3" class="data row8 col3" >(-15.7109084, -47.876274)</td>
#       <td id="T_61af7_row8_col4" class="data row8 col4" >Unidade Básica de Saúde n° 1 Varjão</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_61af7_row9_col0" class="data row9 col0" >UBS 1 CANDANGOLÂNDIA</td>
#       <td id="T_61af7_row9_col1" class="data row9 col1" >UBS 1 CANDANGOLÂNDIA (CSCAN01) EQ 5 7 AREA ESPECIAL - CANDANGOLANDIA 01, CANDANGOLANDIA, Brasília-DF, 71725- 400</td>
#       <td id="T_61af7_row9_col2" class="data row9 col2" >Região Centro - Sul</td>
#       <td id="T_61af7_row9_col3" class="data row9 col3" >(-15.8498126, -47.9513927)</td>
#       <td id="T_61af7_row9_col4" class="data row9 col4" >UBS 01 - Candangolândia</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_61af7_row10_col0" class="data row10 col0" >UBS 1 ESTRUTURAL</td>
#       <td id="T_61af7_row10_col1" class="data row10 col1" >UBS 1 - ESTRUTURA, AREA ESPECIAL 02 AVENIDA CENTRAL CENTRO DE SAUDE 02, ESTRUTURAL, Brasília-DF, 71020-010</td>
#       <td id="T_61af7_row10_col2" class="data row10 col2" >Região Centro - Sul</td>
#       <td id="T_61af7_row10_col3" class="data row10 col3" >(-15.7836414, -47.9972336)</td>
#       <td id="T_61af7_row10_col4" class="data row10 col4" >UBS 1 da Estrutural</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_61af7_row11_col0" class="data row11 col0" >UBS 1 GUARÁ</td>
#       <td id="T_61af7_row11_col1" class="data row11 col1" >UBS 1 GUARÁ (CSGU01), QI 06 AREA ESPECIAL LT A 1, GUARA I, Brasília-DF, 71010-634</td>
#       <td id="T_61af7_row11_col2" class="data row11 col2" >Região Centro - Sul</td>
#       <td id="T_61af7_row11_col3" class="data row11 col3" >(-15.818235, -47.986366)</td>
#       <td id="T_61af7_row11_col4" class="data row11 col4" >Vacinação COVID-19 - UBS 1 Guará</td>
#     </tr>
#     <tr>
#       <th id="T_61af7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_61af

# %%
unidades.drop([30,31,32]).reset_index()
# Out:
#      index                UBS  \
# 0        0      UBS 1 ASA SUL
# 1        1     UBS 1 CRUZEIRO
# 2        2   UBS 1 LAGO NORTE
# 3        3    UBS 1 ASA NORTE
# 4        4    UBS 2 ASA NORTE
# ..     ...                ...
# 123    126  UBS 3 SANTA MARIA
# 124    127  UBS 5 SANTA MARIA
# 125    128  UBS 6 SANTA MARIA
# 126    129  UBS 7 SANTA MARIA
# 127    130  UBS 8 SANTA MARIA
#
#                                               ENDEREÇO REGIONAL DE SAÚDE  \
# 0    UBS 1 ASA SUL (CSB08), SGAS QUADRA 612 LOTES S...    Região Central
# 1    UBS 1 CRUZEIRO (CSB09), Shces Quadra, 611 - Cr...    Região Central
# 2    UBS 1 LAGO NORTE (CSB10), SHIN QI 3 03, LAGO N...    Região Central
# 3    UBS 1 ASA NORTE (CSB11), SGAN 905, ASA NORTE, ...    Região Central
# 4    UBS 2 ASA NORTE (CSB13), Eqn 208 408, 208 - As...    Região Central
# ..                                                 ...               ...
# 123  UBS 3 - SANTA MARIA, Qr 100 Conj I Lote, 1 - S...        Região Sul
# 124  UBS 5 - SANTA MARIA, Eq 212 213 Lote E, 1 - Sa...        Região Sul
# 125  UBS 6 - SANTA MARIA, Qr 202 302 Lote 2, 2 - Sa...        Região Sul
# 126  UBS 7 - SANTA MARIA, Av Brigadeiro Pinto de Mo...        Região Sul
# 127  UBS 8 SANTA MARIA, EQ 417/517 MDE, Brasília - ...        Região Sul
#
#                                    coordinates  \
# 0                    (-15.8326601, -47.909503)
# 1                     (-15.800795, -47.942134)
# 2                   (-15.7257082, -47.8739439)
# 3            (-15.7732459, -47.89242780000001)
# 4                   (-15.7616704, -47.8805846)
# ..                                         ...
# 123  (-16.046903804013322, -48.03679898512468)
# 124  (-16.01032982549102, -48.002362702072205)
# 125                  (-16.040087, -48.0306225)
# 126                 (-15.9932117, -47.9879706)
# 127                  (-16.014494, -47.9883988)
#
#                                       google maps name
# 0                    Unidade Básica de Saúde 1 Asa Sul
# 1                          UBS 01 Cruzeiro Novo (GSAP)
# 2    Vacinação COVID-19 - UBS 1 Lago Norte (Centro ...
# 3                                  SAP 01 da Asa Norte
# 4                                                CEDOH
# ..                                                 ...
# 123                               UBS 03 - Santa Maria
# 124   Unidade Básica de Saúde 5 - UBS 5 DE SANTA MARIA
# 125                               UBS 06 - Santa Maria
# 126                               Ubs 7 de Santa Maria
# 127           UNIDADE BÁSICA DE SAÚDE N° 8 SANTA MARIA
#
# [128 rows x 6 columns]

# %% [markdown]
# ## Get distances

# %%
coordenadas_unidades = list(unidades['coordinates'])

# %%
centros = pd.read_csv('Centros.csv', delimiter=',')
nomes_centros = list(centros['centros'])

# %%
df = pd.DataFrame(columns = nomes_centros)

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_f83d7 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_f83d7 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_f83d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f83d7_level0_col0" class="col_heading level0 col0" >Hospital Regional da Asa Norte</th>
#       <th id="T_f83d7_level0_col1" class="col_heading level0 col1" >Hospital Regional da Ceilândia</th>
#       <th id="T_f83d7_level0_col2" class="col_heading level0 col2" >Hospital Regional do Gama</th>
#       <th id="T_f83d7_level0_col3" class="col_heading level0 col3" >Hospital Regional do Paranoá</th>
#       <th id="T_f83d7_level0_col4" class="col_heading level0 col4" >Hospital Regional de Planaltina</th>
#       <th id="T_f83d7_level0_col5" class="col_heading level0 col5" >Hospital Regional de Taguatinga</th>
#       <th id="T_f83d7_level0_col6" class="col_heading level0 col6" >Hospital Regional de Sobradinho</th>
#       <th id="T_f83d7_level0_col7" class="col_heading level0 col7" >UBS 1 - Núcleo Bandeirante</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
for j in nomes_centros:
    for i in coordenadas_unidades:
        try:
            df.at[i,j] = client.distance_matrix(origins=j,destinations=i.replace('(','').replace(')',''), mode='driving')['rows'][0]['elements'][0]['distance']['value']
        except:
            if j == 'Hospital Regional do Gama':
                try:
                    df.at[i,j] = client.distance_matrix(origins='-16.023317, -48.068846',destinations=i.replace('(','').replace(')',''), mode='driving')['rows'][0]['elements'][0]['distance']['value']
                except:
                    print(i, j)
            else:
                print(i, j)

# %%
#df = df.reset_index()
#df.rename(columns = {'Unnamed: 0':'Coordenadas'}, inplace = True)
df = df.drop(columns=['level_0'])

# %%
df = df.reset_index()

# %%
df['UBS ou ponto de vacinação'] = unidades.drop([30,31,32]).reset_index()['UBS']
df['Nome Google Maps'] = unidades.drop([30,31,32]).reset_index()['google maps name']
df['coordinates	'] = unidades.drop([30,31,32]).reset_index()['coordinates']

# %%
df = df.drop(columns=['UBS ou ponto de vacinação', 'Nome Google Maps'])

# %% [markdown]
# ## Export

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_a8153 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_a8153 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_a8153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8153_level0_col0" class="col_heading level0 col0" >Hospital Regional da Asa Norte</th>
#       <th id="T_a8153_level0_col1" class="col_heading level0 col1" >Hospital Regional da Ceilândia</th>
#       <th id="T_a8153_level0_col2" class="col_heading level0 col2" >Hospital Regional do Gama</th>
#       <th id="T_a8153_level0_col3" class="col_heading level0 col3" >Hospital Regional do Paranoá</th>
#       <th id="T_a8153_level0_col4" class="col_heading level0 col4" >Hospital Regional de Planaltina</th>
#       <th id="T_a8153_level0_col5" class="col_heading level0 col5" >Hospital Regional de Taguatinga</th>
#       <th id="T_a8153_level0_col6" class="col_heading level0 col6" >Hospital Regional de Sobradinho</th>
#       <th id="T_a8153_level0_col7" class="col_heading level0 col7" >UBS 1 - Núcleo Bandeirante</th>
#       <th id="T_a8153_level0_col8" class="col_heading level0 col8" >UBS ou ponto de vacinação</th>
#       <th id="T_a8153_level0_col9" class="col_heading level0 col9" >Nome Google Maps</th>
#       <th id="T_a8153_level0_col10" class="col_heading level0 col10" >coordinates	</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8153_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8153_row0_col0" class="data row0 col0" >8997</td>
#       <td id="T_a8153_row0_col1" class="data row0 col1" >27385</td>
#       <td id="T_a8153_row0_col2" class="data row0 col2" >30544</td>
#       <td id="T_a8153_row0_col3" class="data row0 col3" >23025</td>
#       <td id="T_a8153_row0_col4" class="data row0 col4" >52194</td>
#       <td id="T_a8153_row0_col5" class="data row0 col5" >21739</td>
#       <td id="T_a8153_row0_col6" class="data row0 col6" >34686</td>
#       <td id="T_a8153_row0_col7" class="data row0 col7" >10494</td>
#       <td id="T_a8153_row0_col8" class="data row0 col8" >UBS 1 ASA SUL</td>
#       <td id="T_a8153_row0_col9" class="data row0 col9" >Unidade Básica de Saúde 1 Asa Sul</td>
#       <td id="T_a8153_row0_col10" class="data row0 col10" >(-15.8326601, -47.909503)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8153_row1_col0" class="data row1 col0" >9577</td>
#       <td id="T_a8153_row1_col1" class="data row1 col1" >21300</td>
#       <td id="T_a8153_row1_col2" class="data row1 col2" >31480</td>
#       <td id="T_a8153_row1_col3" class="data row1 col3" >30722</td>
#       <td id="T_a8153_row1_col4" class="data row1 col4" >45078</td>
#       <td id="T_a8153_row1_col5" class="data row1 col5" >18944</td>
#       <td id="T_a8153_row1_col6" class="data row1 col6" >27570</td>
#       <td id="T_a8153_row1_col7" class="data row1 col7" >9379</td>
#       <td id="T_a8153_row1_col8" class="data row1 col8" >UBS 1 CRUZEIRO</td>
#       <td id="T_a8153_row1_col9" class="data row1 col9" >UBS 01 Cruzeiro Novo (GSAP)</td>
#       <td id="T_a8153_row1_col10" class="data row1 col10" >(-15.800795, -47.942134)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8153_row2_col0" class="data row2 col0" >10502</td>
#       <td id="T_a8153_row2_col1" class="data row2 col1" >30682</td>
#       <td id="T_a8153_row2_col2" class="data row2 col2" >44216</td>
#       <td id="T_a8153_row2_col3" class="data row2 col3" >19157</td>
#       <td id="T_a8153_row2_col4" class="data row2 col4" >37801</td>
#       <td id="T_a8153_row2_col5" class="data row2 col5" >29055</td>
#       <td id="T_a8153_row2_col6" class="data row2 col6" >20293</td>
#       <td id="T_a8153_row2_col7" class="data row2 col7" >22114</td>
#       <td id="T_a8153_row2_col8" class="data row2 col8" >UBS 1 LAGO NORTE</td>
#       <td id="T_a8153_row2_col9" class="data row2 col9" >Vacinação COVID-19 - UBS 1 Lago Norte (Centro de Saúde n°10)</td>
#       <td id="T_a8153_row2_col10" class="data row2 col10" >(-15.7257082, -47.8739439)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8153_row3_col0" class="data row3 col0" >2471</td>
#       <td id="T_a8153_row3_col1" class="data row3 col1" >27777</td>
#       <td id="T_a8153_row3_col2" class="data row3 col2" >41310</td>
#       <td id="T_a8153_row3_col3" class="data row3 col3" >22218</td>
#       <td id="T_a8153_row3_col4" class="data row3 col4" >41099</td>
#       <td id="T_a8153_row3_col5" class="data row3 col5" >26149</td>
#       <td id="T_a8153_row3_col6" class="data row3 col6" >23591</td>
#       <td id="T_a8153_row3_col7" class="data row3 col7" >19209</td>
#       <td id="T_a8153_row3_col8" class="data row3 col8" >UBS 1 ASA NORTE</td>
#       <td id="T_a8153_row3_col9" class="data row3 col9" >SAP 01 da Asa Norte</td>
#       <td id="T_a8153_row3_col10" class="data row3 col10" >(-15.7732459, -47.89242780000001)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8153_row4_col0" class="data row4 col0" >3637</td>
#       <td id="T_a8153_row4_col1" class="data row4 col1" >33149</td>
#       <td id="T_a8153_row4_col2" class="data row4 col2" >38972</td>
#       <td id="T_a8153_row4_col3" class="data row4 col3" >24150</td>
#       <td id="T_a8153_row4_col4" class="data row4 col4" >39998</td>
#       <td id="T_a8153_row4_col5" class="data row4 col5" >31521</td>
#       <td id="T_a8153_row4_col6" class="data row4 col6" >22490</td>
#       <td id="T_a8153_row4_col7" class="data row4 col7" >18923</td>
#       <td id="T_a8153_row4_col8" class="data row4 col8" >UBS 2 ASA NORTE</td>
#       <td id="T_a8153_row4_col9" class="data row4 col9" >CEDOH</td>
#       <td id="T_a8153_row4_col10" class="data row4 col10" >(-15.7616704, -47.8805846)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8153_row5_col0" class="data row5 col0" >8591</td>
#       <td id="T_a8153_row5_col1" class="data row5 col1" >32650</td>
#       <td id="T_a8153_row5_col2" class="data row5 col2" >38803</td>
#       <td id="T_a8153_row5_col3" class="data row5 col3" >17027</td>
#       <td id="T_a8153_row5_col4" class="data row5 col4" >46919</td>
#       <td id="T_a8153_row5_col5" class="data row5 col5" >31724</td>
#       <td id="T_a8153_row5_col6" class="data row5 col6" >29411</td>
#       <td id="T_a8153_row5_col7" class="data row5 col7" >18183</td>
#       <td id="T_a8153_row5_col8" class="data row5 col8" >UBS 3 ASA NORTE</td>
#       <td id="T_a8153_row5_col9" class="data row5 col9" >Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto</td>
#       <td id="T_a8153_row5_col10" class="data row5 col10" >(-15.7951717, -47.8481369)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8153_row6_col0" class="data row6 col0" >11056</td>
#       <td id="T_a8153_row6_col1" class="data row6 col1" >29670</td>
#       <td id="T_a8153_row6_col2" class="data row6 col2" >43203</td>
#       <td id="T_a8153_row6_col3" class="data row6 col3" >21243</td>
#       <td id="T_a8153_row6_col4" class="data row6 col4" >34454</td>
#       <td id="T_a8153_row6_col5" class="data row6 col5" >28042</td>
#       <td id="T_a8153_row6_col6" class="data row6 col6" >16946</td>
#       <td id="T_a8153_row6_col7" class="data row6 col7" >21102</td>
#       <td id="T_a8153_row6_col8" class="data row6 col8" >UBS 5 ASA NORTE</td>
#       <td id="T_a8153_row6_col9" class="data row6 col9" >Residência Oficial da Granja do Torto</td>
#       <td id="T_a8153_row6_col10" class="data row6 col10" >(-15.705292, -47.9059388)</td>
#     </tr>
#     <tr>
#       <th id="T_a8153_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8153_row7_col0" class="data row7 col0" >7677</td>
#       <td id="T_a8153_row7_col1" class="

# %%
df.to_csv('Matriz de distâncias final - 131 unidades.csv')

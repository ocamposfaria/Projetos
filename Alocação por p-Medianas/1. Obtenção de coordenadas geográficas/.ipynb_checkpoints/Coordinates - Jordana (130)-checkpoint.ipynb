# %% [markdown]
# ## Import libraries and data

# %%
import pandas as pd
import googlemaps

# %%
with open(r'..\..\..\Google API key.txt') as f:
    secret = f.readlines()[0]
client = googlemaps.Client(key = secret)

# %%
df = pd.read_excel('Lista Jordana.xlsx', sheet_name='Planilha1')

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_455d6 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_455d6 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_455d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_455d6_level0_col0" class="col_heading level0 col0" >Column1</th>
#       <th id="T_455d6_level0_col1" class="col_heading level0 col1" >UBS</th>
#       <th id="T_455d6_level0_col2" class="col_heading level0 col2" >ENDEREÇO</th>
#       <th id="T_455d6_level0_col3" class="col_heading level0 col3" >REGIONAL DE SAÚDE</th>
#       <th id="T_455d6_level0_col4" class="col_heading level0 col4" >coordinates</th>
#       <th id="T_455d6_level0_col5" class="col_heading level0 col5" >google maps name</th>
#       <th id="T_455d6_level0_col6" class="col_heading level0 col6" >ok?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_455d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_455d6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_455d6_row0_col1" class="data row0 col1" >UBS 1 ASA SUL</td>
#       <td id="T_455d6_row0_col2" class="data row0 col2" >UBS 1 ASA SUL (CSB08), SGAS QUADRA 612 LOTES S/N, ASA SUL, Brasília-DF, 70200-720</td>
#       <td id="T_455d6_row0_col3" class="data row0 col3" >Região Central</td>
#       <td id="T_455d6_row0_col4" class="data row0 col4" >(-15.8326601, -47.909503)</td>
#       <td id="T_455d6_row0_col5" class="data row0 col5" >Unidade Básica de Saúde 1 Asa Sul</td>
#       <td id="T_455d6_row0_col6" class="data row0 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_455d6_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_455d6_row1_col1" class="data row1 col1" >UBS 1 CRUZEIRO</td>
#       <td id="T_455d6_row1_col2" class="data row1 col2" >UBS 1 CRUZEIRO (CSB09), Shces Quadra, 611 - Cruzeiro Novo, Brasília - DF, 70070-710</td>
#       <td id="T_455d6_row1_col3" class="data row1 col3" >Região Central</td>
#       <td id="T_455d6_row1_col4" class="data row1 col4" >(-15.800795, -47.942134)</td>
#       <td id="T_455d6_row1_col5" class="data row1 col5" >UBS 01 Cruzeiro Novo (GSAP)</td>
#       <td id="T_455d6_row1_col6" class="data row1 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_455d6_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_455d6_row2_col1" class="data row2 col1" >UBS 1 LAGO NORTE</td>
#       <td id="T_455d6_row2_col2" class="data row2 col2" >UBS 1 LAGO NORTE (CSB10), SHIN QI 3 03, LAGO NORTE, Brasília-DF, 71505-600</td>
#       <td id="T_455d6_row2_col3" class="data row2 col3" >Região Central</td>
#       <td id="T_455d6_row2_col4" class="data row2 col4" >(-15.7257082, -47.8739439)</td>
#       <td id="T_455d6_row2_col5" class="data row2 col5" >Vacinação COVID-19 - UBS 1 Lago Norte (Centro de Saúde n°10)</td>
#       <td id="T_455d6_row2_col6" class="data row2 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_455d6_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_455d6_row3_col1" class="data row3 col1" >UBS 1 ASA NORTE</td>
#       <td id="T_455d6_row3_col2" class="data row3 col2" >UBS 1 ASA NORTE (CSB11), SGAN 905, ASA NORTE, Brasília-DF, 70790-054</td>
#       <td id="T_455d6_row3_col3" class="data row3 col3" >Região Central</td>
#       <td id="T_455d6_row3_col4" class="data row3 col4" >(-15.7732459, -47.89242780000001)</td>
#       <td id="T_455d6_row3_col5" class="data row3 col5" >SAP 01 da Asa Norte</td>
#       <td id="T_455d6_row3_col6" class="data row3 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_455d6_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_455d6_row4_col1" class="data row4 col1" >UBS 2 ASA NORTE</td>
#       <td id="T_455d6_row4_col2" class="data row4 col2" >UBS 2 ASA NORTE (CSB13), Eqn 208 408, 208 - Asa Norte, Brasília - DF, 70853-450</td>
#       <td id="T_455d6_row4_col3" class="data row4 col3" >Região Central</td>
#       <td id="T_455d6_row4_col4" class="data row4 col4" >(-15.7616704, -47.8805846)</td>
#       <td id="T_455d6_row4_col5" class="data row4 col5" >CEDOH</td>
#       <td id="T_455d6_row4_col6" class="data row4 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_455d6_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_455d6_row5_col1" class="data row5 col1" >UBS 3 ASA NORTE</td>
#       <td id="T_455d6_row5_col2" class="data row5 col2" >UBS 3 ASA NORTE, Rua Piau Acampamento Pacheco Fernandes, Área Especial, Vila Planalto, 2, Brasília - DF, 70804-190</td>
#       <td id="T_455d6_row5_col3" class="data row5 col3" >Região Central</td>
#       <td id="T_455d6_row5_col4" class="data row5 col4" >(-15.7951717, -47.8481369)</td>
#       <td id="T_455d6_row5_col5" class="data row5 col5" >Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto</td>
#       <td id="T_455d6_row5_col6" class="data row5 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_455d6_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_455d6_row6_col1" class="data row6 col1" >UBS 5 ASA NORTE</td>
#       <td id="T_455d6_row6_col2" class="data row6 col2" >UBS 5 ASA NORTE, Vila Weslian Roriz , Área Especial, 1, Granja do Torto, Lago Norte, Brasília - DF, 70636-003</td>
#       <td id="T_455d6_row6_col3" class="data row6 col3" >Região Central</td>
#       <td id="T_455d6_row6_col4" class="data row6 col4" >(-15.705292, -47.9059388)</td>
#       <td id="T_455d6_row6_col5" class="data row6 col5" >Residência Oficial da Granja do Torto</td>
#       <td id="T_455d6_row6_col6" class="data row6 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_455d6_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_455d6_row7_col1" class="data row7 col1" >UBS 2 CRUZEIRO</td>
#       <td id="T_455d6_row7_col2" class="data row7 col2" >UBS 2 CRUZEIRO (CSB14), Shce Setor Escolar Lote, 4 - Cruzeiro Velho, Brasília - DF, 70070-710</td>
#       <td id="T_455d6_row7_col3" class="data row7 col3" >Região Central</td>
#       <td id="T_455d6_row7_col4" class="data row7 col4" >(-15.7835664, -47.9359858)</td>
#       <td id="T_455d6_row7_col5" class="data row7 col5" >Unidade Básica de Saúde (UBS) 2 Cruzeiro</td>
#       <td id="T_455d6_row7_col6" class="data row7 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_455d6_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_455d6_row8_col1" class="data row8 col1" >UBS 1 VARJÃO</td>
#       <td id="T_455d6_row8_col2" class="data row8 col2" >UBS 1 VARJÃO (CSB16), VILA VARJAO QUADRA 5 05, VILA VARJAO DO TORTO, Brasília-DF, 71555-133</td>
#       <td id="T_455d6_row8_col3" class="data row8 col3" >Região Central</td>
#       <td id="T_455d6_row8_col4" class="data row8 col4" >(-15.7109084, -47.876274)</td>
#       <td id="T_455d6_row8_col5" class="data row8 col5" >Unidade Básica de Saúde n° 1 Varjão</td>
#       <td id="T_455d6_row8_col6" class="data row8 col6" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_455d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_455d6_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_455d6_row9_col1" class="data row9 col1" >UBS 1 CANDANGOLÂNDIA</td>
#       <td id="T_455d6_row9_col2" class="data row9 col2" >UBS 1 CANDANGOLÂNDIA (CSCAN01) EQ 5 7 AREA ESPECIAL - CANDANGOLANDIA 01, CANDANGOLANDIA, Brasília-DF, 71725- 400</td>
#       <td id="T_455d6_row9_col3" class="data row9 col3" >Região Centro - Sul</td>
#       <td id="T_455d6_row9_col4" class="data row9 col4" >(-15.8498126, -47.9513927)</td>
#       <td id="T_4

# %% [markdown]
# ## Get coordinates

# %%
def get_coordinates(row):
    try:
        var = client.find_place(input=row['ENDEREÇO'], input_type='textquery', fields=['geometry'], language='portuguese')
        coordinates = (var['candidates'][0]['geometry']['location']['lat'], var['candidates'][0]['geometry']['location']['lng'])
    except:
        coordinates = 'NA'
    return coordinates

# %%
def get_google_maps_name(row):
    try:
        var = client.find_place(input=row['ENDEREÇO'], input_type='textquery', fields=['name'], language='portuguese')
        name = var['candidates'][0]['name']
    except:
        name = 'NA'
    return name

# %%
df['coordinates'] = df.apply(get_coordinates, axis=1)
df['google maps name'] = df.apply(get_google_maps_name, axis=1)

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_4b766 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_4b766 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_4b766">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b766_level0_col0" class="col_heading level0 col0" >UBS</th>
#       <th id="T_4b766_level0_col1" class="col_heading level0 col1" >ENDEREÇO</th>
#       <th id="T_4b766_level0_col2" class="col_heading level0 col2" >REGIONAL DE SAÚDE</th>
#       <th id="T_4b766_level0_col3" class="col_heading level0 col3" >coordinates</th>
#       <th id="T_4b766_level0_col4" class="col_heading level0 col4" >google maps name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b766_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b766_row0_col0" class="data row0 col0" >UBS 1 ASA SUL</td>
#       <td id="T_4b766_row0_col1" class="data row0 col1" >UBS 1 ASA SUL (CSB08), SGAS QUADRA 612 LOTES S/N, ASA SUL, Brasília-DF, 70200-720</td>
#       <td id="T_4b766_row0_col2" class="data row0 col2" >Região Central</td>
#       <td id="T_4b766_row0_col3" class="data row0 col3" >(-15.8326601, -47.909503)</td>
#       <td id="T_4b766_row0_col4" class="data row0 col4" >Unidade Básica de Saúde 1 Asa Sul</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b766_row1_col0" class="data row1 col0" >UBS 1 CRUZEIRO</td>
#       <td id="T_4b766_row1_col1" class="data row1 col1" >UBS 1 CRUZEIRO (CSB09), Shces Quadra, 611 - Cruzeiro Novo, Brasília - DF, 70070-710</td>
#       <td id="T_4b766_row1_col2" class="data row1 col2" >Região Central</td>
#       <td id="T_4b766_row1_col3" class="data row1 col3" >NA</td>
#       <td id="T_4b766_row1_col4" class="data row1 col4" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b766_row2_col0" class="data row2 col0" >UBS 1 LAGO NORTE</td>
#       <td id="T_4b766_row2_col1" class="data row2 col1" >UBS 1 LAGO NORTE (CSB10), SHIN QI 3 03, LAGO NORTE, Brasília-DF, 71505-600</td>
#       <td id="T_4b766_row2_col2" class="data row2 col2" >Região Central</td>
#       <td id="T_4b766_row2_col3" class="data row2 col3" >(-15.7257082, -47.8739439)</td>
#       <td id="T_4b766_row2_col4" class="data row2 col4" >Vacinação COVID-19 - UBS 1 Lago Norte (Centro de Saúde n°10)</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b766_row3_col0" class="data row3 col0" >UBS 1 ASA NORTE</td>
#       <td id="T_4b766_row3_col1" class="data row3 col1" >UBS 1 ASA NORTE (CSB11), SGAN 905, ASA NORTE, Brasília-DF, 70790-054</td>
#       <td id="T_4b766_row3_col2" class="data row3 col2" >Região Central</td>
#       <td id="T_4b766_row3_col3" class="data row3 col3" >(-15.7732459, -47.89242780000001)</td>
#       <td id="T_4b766_row3_col4" class="data row3 col4" >SAP 01 da Asa Norte</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b766_row4_col0" class="data row4 col0" >UBS 2 ASA NORTE</td>
#       <td id="T_4b766_row4_col1" class="data row4 col1" >UBS 2 ASA NORTE (CSB13), Eqn 208 408, 208 - Asa Norte, Brasília - DF, 70853-450</td>
#       <td id="T_4b766_row4_col2" class="data row4 col2" >Região Central</td>
#       <td id="T_4b766_row4_col3" class="data row4 col3" >(-15.7616704, -47.8805846)</td>
#       <td id="T_4b766_row4_col4" class="data row4 col4" >CEDOH</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b766_row5_col0" class="data row5 col0" >UBS 3 ASA NORTE</td>
#       <td id="T_4b766_row5_col1" class="data row5 col1" >UBS 3 ASA NORTE, Rua Piau Acampamento Pacheco Fernandes, Área Especial, Vila Planalto, 2, Brasília - DF, 70804-190</td>
#       <td id="T_4b766_row5_col2" class="data row5 col2" >Região Central</td>
#       <td id="T_4b766_row5_col3" class="data row5 col3" >(-15.7951717, -47.8481369)</td>
#       <td id="T_4b766_row5_col4" class="data row5 col4" >Unidade Básica de Saúde (UBS) 3 - Asa Norte - Vila Planalto</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4b766_row6_col0" class="data row6 col0" >UBS 5 ASA NORTE</td>
#       <td id="T_4b766_row6_col1" class="data row6 col1" >UBS 5 ASA NORTE, Vila Weslian Roriz , Área Especial, 1, Granja do Torto, Lago Norte, Brasília - DF, 70636-003</td>
#       <td id="T_4b766_row6_col2" class="data row6 col2" >Região Central</td>
#       <td id="T_4b766_row6_col3" class="data row6 col3" >(-15.705292, -47.9059388)</td>
#       <td id="T_4b766_row6_col4" class="data row6 col4" >Residência Oficial da Granja do Torto</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4b766_row7_col0" class="data row7 col0" >UBS 2 CRUZEIRO</td>
#       <td id="T_4b766_row7_col1" class="data row7 col1" >UBS 2 CRUZEIRO (CSB14), Shce Setor Escolar Lote, 4 - Cruzeiro Velho, Brasília - DF, 70070-710</td>
#       <td id="T_4b766_row7_col2" class="data row7 col2" >Região Central</td>
#       <td id="T_4b766_row7_col3" class="data row7 col3" >(-15.7835664, -47.9359858)</td>
#       <td id="T_4b766_row7_col4" class="data row7 col4" >Unidade Básica de Saúde (UBS) 2 Cruzeiro</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b766_row8_col0" class="data row8 col0" >UBS 1 VARJÃO</td>
#       <td id="T_4b766_row8_col1" class="data row8 col1" >UBS 1 VARJÃO (CSB16), VILA VARJAO QUADRA 5 05, VILA VARJAO DO TORTO, Brasília-DF, 71555-133</td>
#       <td id="T_4b766_row8_col2" class="data row8 col2" >Região Central</td>
#       <td id="T_4b766_row8_col3" class="data row8 col3" >(-15.7109084, -47.876274)</td>
#       <td id="T_4b766_row8_col4" class="data row8 col4" >Unidade Básica de Saúde n° 1 Varjão</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b766_row9_col0" class="data row9 col0" >UBS 1 CANDANGOLÂNDIA</td>
#       <td id="T_4b766_row9_col1" class="data row9 col1" >UBS 1 CANDANGOLÂNDIA (CSCAN01) EQ 5 7 AREA ESPECIAL - CANDANGOLANDIA 01, CANDANGOLANDIA, Brasília-DF, 71725- 400</td>
#       <td id="T_4b766_row9_col2" class="data row9 col2" >Região Centro - Sul</td>
#       <td id="T_4b766_row9_col3" class="data row9 col3" >(-15.8498126, -47.9513927)</td>
#       <td id="T_4b766_row9_col4" class="data row9 col4" >UBS 01 - Candangolândia</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4b766_row10_col0" class="data row10 col0" >UBS 1 ESTRUTURAL</td>
#       <td id="T_4b766_row10_col1" class="data row10 col1" >UBS 1 - ESTRUTURA, AREA ESPECIAL 02 AVENIDA CENTRAL CENTRO DE SAUDE 02, ESTRUTURAL, Brasília-DF, 71020-010</td>
#       <td id="T_4b766_row10_col2" class="data row10 col2" >Região Centro - Sul</td>
#       <td id="T_4b766_row10_col3" class="data row10 col3" >(-15.7836414, -47.9972336)</td>
#       <td id="T_4b766_row10_col4" class="data row10 col4" >UBS 1 da Estrutural</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4b766_row11_col0" class="data row11 col0" >UBS 1 GUARÁ</td>
#       <td id="T_4b766_row11_col1" class="data row11 col1" >UBS 1 GUARÁ (CSGU01), QI 06 AREA ESPECIAL LT A 1, GUARA I, Brasília-DF, 71010-634</td>
#       <td id="T_4b766_row11_col2" class="data row11 col2" >Região Centro - Sul</td>
#       <td id="T_4b766_row11_col3" class="data row11 col3" >NA</td>
#       <td id="T_4b766_row11_col4" class="data row11 col4" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_4b766_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4b766_row12_col0" class="data row12 col0" >UBS 1 NÚCLEO BANDEIRANTE</td>
#       <td id="T_4b766_row12_co

# %%
df.to_csv('Lista Final com coordenadas.csv')

# %%
import pandas as pd
import googlemaps
import gmplot

# %%
client = googlemaps.Client(key = 'AIzaSyBU3xNODle9W35YxeAhWsX4P6C0fsxcopY')

# %%
df = pd.read_csv('lista nova.csv', on_bad_lines='skip', delimiter=';')
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_c7032_ thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_c7032_ tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_c7032_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Regiao Administrativa</th>
#       <th class="col_heading level0 col1" >UBS</th>
#       <th class="col_heading level0 col2" >Horario de Funcionamento</th>
#       <th class="col_heading level0 col3" >endereço</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7032_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7032_row0_col0" class="data row0 col0" >AGUAS CLARAS/AREAL</td>
#       <td id="T_c7032_row0_col1" class="data row0 col1" >UBS 1 DE AGUAS CLARAS</td>
# ...

# %%
def endereço(row):
    var = client.find_place(input=row['endereço'], input_type='textquery', fields=["formatted_address", "place_id", "plus_code", "geometry"], language='portuguese')
    return var

def UBS(row):
    var = client.find_place(input=row['UBS'], input_type='textquery', fields=["formatted_address", "place_id", "plus_code", "geometry"], language='portuguese')
    return var

def UBS_concat(row):
    var = client.find_place(input=row['UBS concat'], input_type='textquery', fields=["formatted_address", "place_id", "plus_code", "geometry"], language='portuguese')
    return var

# %%
df['returns by endereço'] = df.apply(endereço, axis=1)
df['returns by UBS'] = df.apply(UBS, axis=1)
df['returns by UBS concat'] = df.apply(UBS_concat, axis=1)

# %%
df['formatted_address3'] = df['returns by UBS concat'].str['candidates'].str[0].str['geometry'].str['location'].str['lat'].astype(str) +', '+ df['returns by UBS concat'].str['candidates'].str[0].str['geometry'].str['location'].str['lng'].astype(str)

# %%
df
# Out:
#     Regiao Administrativa                     UBS  \
# 0      AGUAS CLARAS/AREAL   UBS 1 DE AGUAS CLARAS
# 1      AGUAS CLARAS/AREAL   UBS 2 DE AGUAS CLARAS
# 2               ASA NORTE      UBS 1 DA ASA NORTE
# 3               ASA NORTE      UBS 2 DA ASA NORTE
# 4               ASA NORTE      UBS 3 DA ASA NORTE
# ..                    ...                     ...
# 162            TAGUATINGA     UBS 6 DE TAGUATINGA
# 163            TAGUATINGA     UBS 7 DE TAGUATINGA
# 164            TAGUATINGA     UBS 8 DE TAGUATINGA
# 165                VARJAO         UBS 1 DO VARJAO
# 166         VICENTE PIRES  UBS 1 DE VICENTE PIRES
#
#                           Horario de Funcionamento  \
# 0     07 as 19h segunda a sexta e sabado 07 as 12h
# 1                        07 as 17h segunda a sexta
# 2     07 as 18h segunda a sexta e sabado 07 as 12h
# 3     07 as 19h segunda a sexta e sabado 07 as 12h
# 4                        07 as 18h segunda a sexta
# ...

# %% [markdown]
# ## Google Maps Plot

# %%
import gmplot
apikey = 'AIzaSyBU3xNODle9W35YxeAhWsX4P6C0fsxcopY'
gmap = gmplot.GoogleMapPlotter(-15.7732459, -47.89242780000001, 15, apikey=apikey)

attractions = zip(*[
    (-15.7732459, -47.89242780000001)
])

gmap.scatter(
    *attractions,
    color=['white'],
    s=80,
    ew=4,
    marker=[True],
    symbol=['o'],
    title=['First'],
    label=['A']
)

gmap.draw('map.html')

# %% [markdown]
# ## Import libraries and data

# %%
import gmplot
import pandas as pd
import googlemaps
import gmplot

# %%
df = pd.read_csv(r'..\3. Otimização por p-medianas\Optimized.csv').drop(columns=['Unnamed: 0'])

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_c71bc thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_c71bc tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_c71bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c71bc_level0_col0" class="col_heading level0 col0" >origem</th>
#       <th id="T_c71bc_level0_col1" class="col_heading level0 col1" >destino</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c71bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c71bc_row0_col0" class="data row0 col0" >Hospital Regional da Asa Norte</td>
#       <td id="T_c71bc_row0_col1" class="data row0 col1" >(-15.7431358,-47.89162049999999)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c71bc_row1_col0" class="data row1 col0" >Hospital Regional da Asa Norte</td>
#       <td id="T_c71bc_row1_col1" class="data row1 col1" >(-15.7732459,-47.89242780000001)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c71bc_row2_col0" class="data row2 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row2_col1" class="data row2 col1" >(-15.5389184,-48.1685104)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c71bc_row3_col0" class="data row3 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row3_col1" class="data row3 col1" >(-15.6589014,-48.1930314)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c71bc_row4_col0" class="data row4 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row4_col1" class="data row4 col1" >(-15.6698514,-48.2004701)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c71bc_row5_col0" class="data row5 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row5_col1" class="data row5 col1" >(-15.6728185,-48.2003232)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c71bc_row6_col0" class="data row6 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row6_col1" class="data row6 col1" >(-15.6772371,-48.1949629)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c71bc_row7_col0" class="data row7 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row7_col1" class="data row7 col1" >(-15.7851944,-48.1365487)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c71bc_row8_col0" class="data row8 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row8_col1" class="data row8 col1" >(-15.7956911,-48.1309163)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c71bc_row9_col0" class="data row9 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row9_col1" class="data row9 col1" >(-15.7983005,-48.1336503)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c71bc_row10_col0" class="data row10 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row10_col1" class="data row10 col1" >(-15.8011248,-48.0941947)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c71bc_row11_col0" class="data row11 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row11_col1" class="data row11 col1" >(-15.8031819,-48.1117556)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c71bc_row12_col0" class="data row12 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row12_col1" class="data row12 col1" >(-15.8046599,-48.1434216)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c71bc_row13_col0" class="data row13 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row13_col1" class="data row13 col1" >(-15.8068817,-48.1299527)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c71bc_row14_col0" class="data row14 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row14_col1" class="data row14 col1" >(-15.8078351,-48.1205846)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c71bc_row15_col0" class="data row15 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row15_col1" class="data row15 col1" >(-15.8093579,-48.1563721)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c71bc_row16_col0" class="data row16 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row16_col1" class="data row16 col1" >(-15.8153732,-48.1176118)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c71bc_row17_col0" class="data row17 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row17_col1" class="data row17 col1" >(-15.8186984,-48.130117)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c71bc_row18_col0" class="data row18 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row18_col1" class="data row18 col1" >(-15.8210801,-48.0923058)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c71bc_row19_col0" class="data row19 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row19_col1" class="data row19 col1" >(-15.8245621,-48.11346899999999)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c71bc_row20_col0" class="data row20 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row20_col1" class="data row20 col1" >(-15.8288882,-48.246458)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c71bc_row21_col0" class="data row21 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row21_col1" class="data row21 col1" >(-15.8309646,-48.0966408)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c71bc_row22_col0" class="data row22 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row22_col1" class="data row22 col1" >(-15.8402161,-48.1142165)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c71bc_row23_col0" class="data row23 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row23_col1" class="data row23 col1" >(-15.8465998,-48.1235636)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_c71bc_row24_col0" class="data row24 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row24_col1" class="data row24 col1" >(-15.846837,-48.11453239999999)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_c71bc_row25_col0" class="data row25 col0" >Hospital Regional da Ceilândia</td>
#       <td id="T_c71bc_row25_col1" class="data row25 col1" >(-15.8756717,-48.1099171)</td>
#     </tr>
#     <tr>
#       <th id="T_c71bc_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_c71bc_row26_col0" class="data row26 col0" >Hospital Regional da Ce

# %%
df.shape[0]
# Out:
# 168

# %% [markdown]
# ## Color

# %%
def color(row):
    if row['origem'] == 'Hospital Regional da Asa Norte':
        color = 'yellow'
    if row['origem'] == 'Hospital Regional da Ceilândia':
        color = 'brown'
    if row['origem'] == 'Hospital Regional de Sobradinho':
        color = 'grey'
    if row['origem'] == 'Hospital Regional de Planaltina':
        color = 'green'
    if row['origem'] == 'Hospital Regional de Taguatinga':
        color = 'orange'
    if row['origem'] == 'Hospital Regional do Gama':
        color = 'white'
    if row['origem'] == 'Hospital Regional do Paranoá':
        color = 'red'
    if row['origem'] == 'UBS 1   Núcleo Bandeirante':
        color = 'purple'
    return color

# %%
df['color'] = df.apply(color, axis=1)

# %% [markdown]
# ## Google Maps Plot

# %%
lista = []
for i in df['destino'].to_list():
    lista = lista + [eval(i)]

# %%
import gmplot
apikey = 'AIzaSyBU3xNODle9W35YxeAhWsX4P6C0fsxcopY'
gmap = gmplot.GoogleMapPlotter(-15.788032, -47.745547, 11, apikey=apikey)

attractions = zip(*lista)

gmap.scatter(
    *attractions,
    color=df['color'].to_list(),
    s=100,
    ew=4,
    marker=[True]*df.shape[0],
    symbol=[None]*df.shape[0],
    title=df['destino'].to_list(),
    label=df.index.to_list()
)

gmap.draw('map.html')

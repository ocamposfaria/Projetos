# %% [raw]
# para o método de p-medianas, precisamos de algumas informações:
#
#     1 - localização de todos os pontos de recebimento de vacinas de Covid-19 (UBSs)
#     2 - localização de todos os centros de distribuição, responsáveis pela entrega dessas vacinas
#     3 - com as localizações em mãos, é necessário construir uma matriz de custos de transporte entre os pontos
# (posso considerar que o custo é proporcional  à distância, então isso seria uma matriz de distâncias)
#
# para a formulação completa que FARAHANI, REZAPOUR e KARDAR propõem, também preciso de:
#     4 - uma matriz com os custos (fixos) de abertura de novos centros logísticos
#
# por fim, é claro:
#     5 - variável p de input para a quantidade de núcleos logísticos "abertos"

# %% [markdown]
# ## Imports

# %%
from pulp import *
import googlemaps
import pandas as pd

# %%
#googlemaps.Client(key = 'AIzaSyBU3xNODle9W35YxeAhWsX4P6C0fsxcopY')

# %%
df_unidades = pd.read_csv('unidades de saude.csv', delimiter = ';', decimal=',')
df_centros = pd.read_csv('centros de distribuicao.csv', delimiter = ';', decimal=',')

df = pd.read_csv('matriz final.csv', index_col=0)

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_b88ad_ thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_b88ad_ tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_b88ad_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Hospital Regional da Asa Norte</th>
#       <th class="col_heading level0 col1" >Hospital Regional da Ceilândia</th>
#       <th class="col_heading level0 col2" >Hospital Regional do Gama</th>
#       <th class="col_heading level0 col3" >Hospital Regional do Paranoá</th>
#       <th class="col_heading level0 col4" >Hospital Regional de Planaltina</th>
#       <th class="col_heading level0 col5" >Hospital Regional de Taguatinga</th>
#       <th class="col_heading level0 col6" >Hospital Regional de Sobradinho</th>
#       <th class="col_heading level0 col7" >UBS 1 - Núcleo Bandeirante</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b88ad_level0_row0" class="row_heading level0 row0" >UBS 1 do Lago Norte</th>
#       <td id="T_b88ad_row0_col0" class="data row0 col0" >10509</td>
#       <td id="T_b88ad_row0_col1" class="data row0 col1" >30689</td>
#       <td id="T_b88ad_row0_col2" class="data row0 col2" >43656</td>
#       <td id="T_b88ad_row0_col3" class="data row0 col3" >19164</td>
#       <td id="T_b88ad_row0_col4" class="data row0 col4" >37808</td>
#       <td id="T_b88ad_row0_col5" class="data row0 col5" >29061</td>
#       <td id="T_b88ad_row0_col6" class="data row0 col6" >20300</td>
#       <td id="T_b88ad_row0_col7" class="data row0 col7" >22121</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row1" class="row_heading level0 row1" >UBS 1 do Varjão</th>
#       <td id="T_b88ad_row1_col0" class="data row1 col0" >11538</td>
#       <td id="T_b88ad_row1_col1" class="data row1 col1" >31718</td>
#       <td id="T_b88ad_row1_col2" class="data row1 col2" >44686</td>
#       <td id="T_b88ad_row1_col3" class="data row1 col3" >16046</td>
#       <td id="T_b88ad_row1_col4" class="data row1 col4" >34436</td>
#       <td id="T_b88ad_row1_col5" class="data row1 col5" >30091</td>
#       <td id="T_b88ad_row1_col6" class="data row1 col6" >16928</td>
#       <td id="T_b88ad_row1_col7" class="data row1 col7" >23150</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row2" class="row_heading level0 row2" >UBS 1 da Asa Norte</th>
#       <td id="T_b88ad_row2_col0" class="data row2 col0" >2471</td>
#       <td id="T_b88ad_row2_col1" class="data row2 col1" >27777</td>
#       <td id="T_b88ad_row2_col2" class="data row2 col2" >40744</td>
#       <td id="T_b88ad_row2_col3" class="data row2 col3" >22218</td>
#       <td id="T_b88ad_row2_col4" class="data row2 col4" >41314</td>
#       <td id="T_b88ad_row2_col5" class="data row2 col5" >26149</td>
#       <td id="T_b88ad_row2_col6" class="data row2 col6" >23806</td>
#       <td id="T_b88ad_row2_col7" class="data row2 col7" >19209</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row3" class="row_heading level0 row3" >UBS 2 da Asa Norte</th>
#       <td id="T_b88ad_row3_col0" class="data row3 col0" >6566</td>
#       <td id="T_b88ad_row3_col1" class="data row3 col1" >29880</td>
#       <td id="T_b88ad_row3_col2" class="data row3 col2" >42848</td>
#       <td id="T_b88ad_row3_col3" class="data row3 col3" >20881</td>
#       <td id="T_b88ad_row3_col4" class="data row3 col4" >36946</td>
#       <td id="T_b88ad_row3_col5" class="data row3 col5" >28253</td>
#       <td id="T_b88ad_row3_col6" class="data row3 col6" >19438</td>
#       <td id="T_b88ad_row3_col7" class="data row3 col7" >21312</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row4" class="row_heading level0 row4" >UBS 1 da Asa Sul</th>
#       <td id="T_b88ad_row4_col0" class="data row4 col0" >8997</td>
#       <td id="T_b88ad_row4_col1" class="data row4 col1" >27398</td>
#       <td id="T_b88ad_row4_col2" class="data row4 col2" >29978</td>
#       <td id="T_b88ad_row4_col3" class="data row4 col3" >23025</td>
#       <td id="T_b88ad_row4_col4" class="data row4 col4" >52207</td>
#       <td id="T_b88ad_row4_col5" class="data row4 col5" >21752</td>
#       <td id="T_b88ad_row4_col6" class="data row4 col6" >34699</td>
#       <td id="T_b88ad_row4_col7" class="data row4 col7" >10494</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row5" class="row_heading level0 row5" >UBS 1 do Cruzeiro</th>
#       <td id="T_b88ad_row5_col0" class="data row5 col0" >9579</td>
#       <td id="T_b88ad_row5_col1" class="data row5 col1" >21302</td>
#       <td id="T_b88ad_row5_col2" class="data row5 col2" >30917</td>
#       <td id="T_b88ad_row5_col3" class="data row5 col3" >30724</td>
#       <td id="T_b88ad_row5_col4" class="data row5 col4" >45081</td>
#       <td id="T_b88ad_row5_col5" class="data row5 col5" >18947</td>
#       <td id="T_b88ad_row5_col6" class="data row5 col6" >27573</td>
#       <td id="T_b88ad_row5_col7" class="data row5 col7" >9381</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row6" class="row_heading level0 row6" >Parque da Cidade - Estacionamento 13</th>
#       <td id="T_b88ad_row6_col0" class="data row6 col0" >3812</td>
#       <td id="T_b88ad_row6_col1" class="data row6 col1" >24958</td>
#       <td id="T_b88ad_row6_col2" class="data row6 col2" >36335</td>
#       <td id="T_b88ad_row6_col3" class="data row6 col3" >21182</td>
#       <td id="T_b88ad_row6_col4" class="data row6 col4" >46030</td>
#       <td id="T_b88ad_row6_col5" class="data row6 col5" >23330</td>
#       <td id="T_b88ad_row6_col6" class="data row6 col6" >28522</td>
#       <td id="T_b88ad_row6_col7" class="data row6 col7" >14799</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row7" class="row_heading level0 row7" >Associação Médica de Brasília (Ambr)</th>
#       <td id="T_b88ad_row7_col0" class="data row7 col0" >9052</td>
#       <td id="T_b88ad_row7_col1" class="data row7 col1" >31147</td>
#       <td id="T_b88ad_row7_col2" class="data row7 col2" >36783</td>
#       <td id="T_b88ad_row7_col3" class="data row7 col3" >15324</td>
#       <td id="T_b88ad_row7_col4" class="data row7 col4" >47595</td>
#       <td id="T_b88ad_row7_col5" class="data row7 col5" >30283</td>
#       <td id="T_b88ad_row7_col6" class="data row7 col6" >30087</td>
#       <td id="T_b88ad_row7_col7" class="data row7 col7" >16729</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row8" class="row_heading level0 row8" >UBS 3 Vila Planalto </th>
#       <td id="T_b88ad_row8_col0" class="data row8 col0" >8557</td>
#       <td id="T_b88ad_row8_col1" class="data row8 col1" >32616</td>
#       <td id="T_b88ad_row8_col2" class="data row8 col2" >38204</td>
#       <td id="T_b88ad_row8_col3" class="data row8 col3" >16993</td>
#       <td id="T_b88ad_row8_col4" class="data row8 col4" >47101</td>
#       <td id="T_b88ad_row8_col5" class="data row8 col5" >31704</td>
#       <td id="T_b88ad_row8_col6" class="data row8 col6" >29593</td>
#       <td id="T_b88ad_row8_col7" class="data row8 col7" >18149</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row9" class="row_heading level0 row9" >Praça dos Cristais</th>
#       <td id="T_b88ad_row9_col0" class="data row9 col0" >5991</td>
#       <td id="T_b88ad_row9_col1" class="data row9 col1" >22950</td>
#       <td id="T_b88ad_row9_col2" class="data row9 col2" >37616</td>
#       <td id="T_b88ad_row9_col3" class="data row9 col3" >27490</td>
#       <td id="T_b88ad_row9_col4" class="data row9 col4" >41847</td>
#       <td id="T_b88ad_row9_col5" class="data row9 col5" >21322</td>
#       <td id="T_b88ad_row9_col6" class="data row9 col6" >24339</td>
#       <td id="T_b88ad_row9_col7" class="data row9 col7" >16081</td>
#     </tr>
#     <tr>
#       <th id="T_b88ad_level0_row10" class="row_heading level0 row10" >UBS 1 Sobradinho</th>
#       <td id="T_b88ad_row10_col0" class="data row10 col0" >25344</td>
#       <td id="T_b88ad_row10_col1" class="data row10 col1" >44438</td>
#       <td id="T_b88ad_row10_col2" class="data row10 col2" >57405</td>
#       <td id="T_b88ad_row10_col3" class="data row10 col3" >23893</td>
#       <td id="T_b88ad_row10_col4" c

# %%
unidades = df.index.to_list()
CDs = df.columns.to_list()
df = df.to_dict()

# %% [markdown]
# ## Modeling

# %%
prob = LpProblem("THE_P_MEDIAN_PROBLEM", LpMinimize)

# %%
p = 8

# %%
x = LpVariable.dicts('X_%s_to_%s', (CDs,unidades), 
    cat = 'Binary', 
    lowBound = 0, 
    upBound = 1)

# %%
y = LpVariable.dicts('Y_%s', (CDs),
    cat = 'Binary', 
    lowBound = 0, 
    upBound = 1)

# %%
prob += sum(x[i][j]*df[i][j] for i in CDs for j in unidades), "Distância total entre CDs e unidades"

# %%
# cada unidade deve receber vacinas de um, e apenas um, CD
for j in unidades:
        prob += sum(x[i][j] for i in CDs) == 1

# %%
# a quantodade de CDs abertos é igual a p
prob += lpSum(y[j] for j in CDs) == p

# %%
# apenas CDs abertos podem entregar vacinas
for i in CDs:
    for  j in unidades:
        prob += x[i][j]<= y[i]

# %%
# cada CD só pode atender no máximo 7 unidades
for i in CDs:
    prob += lpSum(x[i][j] for j in unidades) <= 15

# %%
prob
# Out:
# THE_P_MEDIAN_PROBLEM:
# MINIMIZE
# 9052*X_Hospital_Regional_da_Asa_Norte_to_Associação_Médica_de_Brasília_(Ambr) + 41405*X_Hospital_Regional_da_Asa_Norte_to_Centro_Olímpico_de_Planaltina + 19539*X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico + 24355*X_Hospital_Regional_da_Asa_Norte_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião) + 3812*X_Hospital_Regional_da_Asa_Norte_to_Parque_da_Cidade___Estacionamento_13 + 5991*X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Cristais + 31629*X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Direitos_(Ceilândia) + 27188*X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Direitos___Itapoã + 24342*X_Hospital_Regional_da_Asa_Norte_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional) + 25799*X_Hospital_Regional_da_Asa_Norte_to_Regional_de_Ensino_Sobradinho_II + 35490*X_Hospital_Regional_da_Asa_Norte_to_SESI_Gama + 9200*X_Hospital_Regional_da_Asa_Norte_to_Shopping_Iguatemi + 30775*X_Hospital_Regional_da_Asa_Norte_to_UBS_10_de_Ceilândia + 38800*X_Hospital_Regional_da_Asa_Norte_to_UBS_11_Samambaia + 32784*X_Hospital_Regional_da_Asa_Norte_to_UBS_11_de_Ceilândia + 34306*X_Hospital_Regional_da_Asa_Norte_to_UBS_12_de_Ceilândia + 32396*X_Hospital_Regional_da_Asa_Norte_to_UBS_16_de_Ceilândia + 29427*X_Hospital_Regional_da_Asa_Norte_to_UBS_17_de_Ceilândia + 37995*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Gama + 8997*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Santa_Maria + 25344*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Sobradinho + 26286*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Sobradinho_II + 22166*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Taguatinga + 18238*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Vicente_Pires + 2471*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Norte + 8997*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Sul + 14692*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Candangolândia + 14890*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Estrutural + 48986*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_de_Brazlândia + 32631*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_de_Ceilândia + 9579*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Cruzeiro + 14886*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Guará + 21648*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Jardins_Mangueiral + 10509*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Lago_Norte + 16576*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Núcleo_Bandeirante + 23085*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Riacho_Fundo_I + 33770*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Riacho_Fundo_II + 11538*X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Varjão + 38451*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Gama + 41797*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Planaltina + 34055*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Samambaia + 31536*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Santa_Maria + 23650*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Taguatinga + 6566*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Asa_Norte + 15324*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Estrutural + 14963*X_Hospital_Regional_da_Asa_Norte_to_UBS_2_do_Guará + 35061*X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Gama + 31654*X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Recanto_das_Emas + 27098*X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Sobradinho + 8557*X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Vila_Planalto_ + 27132*X_Hospital_Regional_da_Asa_Norte_to_UBS_3_de_Ceilândia + 15763*X_Hospital_Regional_da_Asa_Norte_to_UBS_3_do_Guará + 36962*X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Gama + 35965*X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Planaltina + 35465*X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Recanto_das_Emas + 36427*X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Gama + 41876*X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Planaltina + 24293*X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Samambaia + 24293*X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Taguatinga + 29724*X_Hospital_Regional_da_Asa_Norte_to_UBS_5_de_Ceilândia + 36462*X_Hospital_Regional_da_Asa_Norte_to_UBS_6_Gama + 29491*X_Hospital_Regional_da_Asa ...
# SUBJECT TO
# _C1: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Lago_Norte
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Lago_Norte
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Lago_Norte
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Lago_Norte
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Lago_Norte
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Lago_Norte
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Lago_Norte
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Lago_Norte = 1
#
# _C2: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Varjão
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Varjão
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Varjão
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Varjão
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Varjão
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Varjão
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Varjão
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Varjão = 1
#
# _C3: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Norte
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_da_Asa_Norte
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_da_Asa_Norte
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_da_Asa_Norte
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_da_Asa_Norte
#  + X_Hospital_Regional_do_Gama_to_UBS_1_da_Asa_Norte
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Asa_Norte
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Asa_Norte = 1
#
# _C4: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Asa_Norte
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_da_Asa_Norte
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_da_Asa_Norte
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_da_Asa_Norte
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_da_Asa_Norte
#  + X_Hospital_Regional_do_Gama_to_UBS_2_da_Asa_Norte
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_da_Asa_Norte
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_da_Asa_Norte = 1
#
# _C5: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Sul
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_da_Asa_Sul
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_da_Asa_Sul
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_da_Asa_Sul
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_da_Asa_Sul
#  + X_Hospital_Regional_do_Gama_to_UBS_1_da_Asa_Sul
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Asa_Sul
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Asa_Sul = 1
#
# _C6: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Cruzeiro
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Cruzeiro
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Cruzeiro
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Cruzeiro
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Cruzeiro
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Cruzeiro
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Cruzeiro
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Cruzeiro = 1
#
# _C7: X_Hospital_Regional_da_Asa_Norte_to_Parque_da_Cidade___Estacionamento_13
#  + X_Hospital_Regional_da_Ceilândia_to_Parque_da_Cidade___Estacionamento_13
#  + X_Hospital_Regional_de_Planaltina_to_Parque_da_Cidade___Estacionamento_13
#  + X_Hospital_Regional_de_Sobradinho_to_Parque_da_Cidade___Estacionamento_13
#  + X_Hospital_Regional_de_Taguatinga_to_Parque_da_Cidade___Estacionamento_13
#  + X_Hospital_Regional_do_Gama_to_Parque_da_Cidade___Estacionamento_13
#  + X_Hospital_Regional_do_Paranoá_to_Parque_da_Cidade___Estacionamento_13
#  + X_UBS_1___Núcleo_Bandeirante_to_Parque_da_Cidade___Estacionamento_13 = 1
#
# _C8: X_Hospital_Regional_da_Asa_Norte_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_Hospital_Regional_da_Ceilândia_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_Hospital_Regional_de_Planaltina_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_Hospital_Regional_de_Sobradinho_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_Hospital_Regional_de_Taguatinga_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_Hospital_Regional_do_Gama_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_Hospital_Regional_do_Paranoá_to_Associação_Médica_de_Brasília_(Ambr)
#  + X_UBS_1___Núcleo_Bandeirante_to_Associação_Médica_de_Brasília_(Ambr) = 1
#
# _C9: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Vila_Planalto_
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_3_Vila_Planalto_
#  + X_Hospital_Regional_de_Planaltina_to_UBS_3_Vila_Planalto_
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_3_Vila_Planalto_
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_3_Vila_Planalto_
#  + X_Hospital_Regional_do_Gama_to_UBS_3_Vila_Planalto_
#  + X_Hospital_Regional_do_Paranoá_to_UBS_3_Vila_Planalto_
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Vila_Planalto_ = 1
#
# _C10: X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Cristais
#  + X_Hospital_Regional_da_Ceilândia_to_Praça_dos_Cristais
#  + X_Hospital_Regional_de_Planaltina_to_Praça_dos_Cristais
#  + X_Hospital_Regional_de_Sobradinho_to_Praça_dos_Cristais
#  + X_Hospital_Regional_de_Taguatinga_to_Praça_dos_Cristais
#  + X_Hospital_Regional_do_Gama_to_Praça_dos_Cristais
#  + X_Hospital_Regional_do_Paranoá_to_Praça_dos_Cristais
#  + X_UBS_1___Núcleo_Bandeirante_to_Praça_dos_Cristais = 1
#
# _C11: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Sobradinho
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_Sobradinho
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_Sobradinho
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_Sobradinho
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_Sobradinho
#  + X_Hospital_Regional_do_Gama_to_UBS_1_Sobradinho
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_Sobradinho
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Sobradinho = 1
#
# _C12: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Sobradinho
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_3_Sobradinho
#  + X_Hospital_Regional_de_Planaltina_to_UBS_3_Sobradinho
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_3_Sobradinho
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_3_Sobradinho
#  + X_Hospital_Regional_do_Gama_to_UBS_3_Sobradinho
#  + X_Hospital_Regional_do_Paranoá_to_UBS_3_Sobradinho
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Sobradinho = 1
#
# _C13: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Sobradinho_II
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_Sobradinho_II
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_Sobradinho_II
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_Sobradinho_II
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_Sobradinho_II
#  + X_Hospital_Regional_do_Gama_to_UBS_1_Sobradinho_II
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_Sobradinho_II
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Sobradinho_II = 1
#
# _C14: X_Hospital_Regional_da_Asa_Norte_to_Regional_de_Ensino_Sobradinho_II
#  + X_Hospital_Regional_da_Ceilândia_to_Regional_de_Ensino_Sobradinho_II
#  + X_Hospital_Regional_de_Planaltina_to_Regional_de_Ensino_Sobradinho_II
#  + X_Hospital_Regional_de_Sobradinho_to_Regional_de_Ensino_Sobradinho_II
#  + X_Hospital_Regional_de_Taguatinga_to_Regional_de_Ensino_Sobradinho_II
#  + X_Hospital_Regional_do_Gama_to_Regional_de_Ensino_Sobradinho_II
#  + X_Hospital_Regional_do_Paranoá_to_Regional_de_Ensino_Sobradinho_II
#  + X_UBS_1___Núcleo_Bandeirante_to_Regional_de_Ensino_Sobradinho_II = 1
#
# _C15: X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Planaltina
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_4_Planaltina
#  + X_Hospital_Regional_de_Planaltina_to_UBS_4_Planaltina
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_4_Planaltina
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_4_Planaltina
#  + X_Hospital_Regional_do_Gama_to_UBS_4_Planaltina
#  + X_Hospital_Regional_do_Paranoá_to_UBS_4_Planaltina
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_4_Planaltina = 1
#
# _C16: X_Hospital_Regional_da_Asa_Norte_to_Centro_Olímpico_de_Planaltina
#  + X_Hospital_Regional_da_Ceilândia_to_Centro_Olímpico_de_Planaltina
#  + X_Hospital_Regional_de_Planaltina_to_Centro_Olímpico_de_Planaltina
#  + X_Hospital_Regional_de_Sobradinho_to_Centro_Olímpico_de_Planaltina
#  + X_Hospital_Regional_de_Taguatinga_to_Centro_Olímpico_de_Planaltina
#  + X_Hospital_Regional_do_Gama_to_Centro_Olímpico_de_Planaltina
#  + X_Hospital_Regional_do_Paranoá_to_Centro_Olímpico_de_Planaltina
#  + X_UBS_1___Núcleo_Bandeirante_to_Centro_Olímpico_de_Planaltina = 1
#
# _C17: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Planaltina
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_Planaltina
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_Planaltina
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_Planaltina
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_Planaltina
#  + X_Hospital_Regional_do_Gama_to_UBS_2_Planaltina
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_Planaltina
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Planaltina = 1
#
# _C18: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Planaltina
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_5_Planaltina
#  + X_Hospital_Regional_de_Planaltina_to_UBS_5_Planaltina
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_5_Planaltina
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_5_Planaltina
#  + X_Hospital_Regional_do_Gama_to_UBS_5_Planaltina
#  + X_Hospital_Regional_do_Paranoá_to_UBS_5_Planaltina
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Planaltina = 1
#
# _C19: X_Hospital_Regional_da_Asa_Norte_to_SESI_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_SESI_Gama
#  + X_Hospital_Regional_de_Planaltina_to_SESI_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_SESI_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_SESI_Gama
#  + X_Hospital_Regional_do_Gama_to_SESI_Gama
#  + X_Hospital_Regional_do_Paranoá_to_SESI_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_SESI_Gama = 1
#
# _C20: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_Gama
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_Gama
#  + X_Hospital_Regional_do_Gama_to_UBS_1_Gama
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Gama = 1
#
# _C21: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_Gama
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_Gama
#  + X_Hospital_Regional_do_Gama_to_UBS_2_Gama
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Gama = 1
#
# _C22: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_3_Gama
#  + X_Hospital_Regional_de_Planaltina_to_UBS_3_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_3_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_3_Gama
#  + X_Hospital_Regional_do_Gama_to_UBS_3_Gama
#  + X_Hospital_Regional_do_Paranoá_to_UBS_3_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Gama = 1
#
# _C23: X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_4_Gama
#  + X_Hospital_Regional_de_Planaltina_to_UBS_4_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_4_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_4_Gama
#  + X_Hospital_Regional_do_Gama_to_UBS_4_Gama
#  + X_Hospital_Regional_do_Paranoá_to_UBS_4_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_4_Gama = 1
#
# _C24: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_5_Gama
#  + X_Hospital_Regional_de_Planaltina_to_UBS_5_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_5_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_5_Gama
#  + X_Hospital_Regional_do_Gama_to_UBS_5_Gama
#  + X_Hospital_Regional_do_Paranoá_to_UBS_5_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Gama = 1
#
# _C25: X_Hospital_Regional_da_Asa_Norte_to_UBS_6_Gama
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_6_Gama
#  + X_Hospital_Regional_de_Planaltina_to_UBS_6_Gama
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_6_Gama
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_6_Gama
#  + X_Hospital_Regional_do_Gama_to_UBS_6_Gama
#  + X_Hospital_Regional_do_Paranoá_to_UBS_6_Gama
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_6_Gama = 1
#
# _C26: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Santa_Maria
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_Santa_Maria
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_Santa_Maria
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_Santa_Maria
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_Santa_Maria
#  + X_Hospital_Regional_do_Gama_to_UBS_1_Santa_Maria
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_Santa_Maria
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Santa_Maria = 1
#
# _C27: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Santa_Maria
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_Santa_Maria
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_Santa_Maria
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_Santa_Maria
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_Santa_Maria
#  + X_Hospital_Regional_do_Gama_to_UBS_2_Santa_Maria
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_Santa_Maria
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Santa_Maria = 1
#
# _C28: X_Hospital_Regional_da_Asa_Norte_to_UNIEURO_Águas_Claras
#  + X_Hospital_Regional_da_Ceilândia_to_UNIEURO_Águas_Claras
#  + X_Hospital_Regional_de_Planaltina_to_UNIEURO_Águas_Claras
#  + X_Hospital_Regional_de_Sobradinho_to_UNIEURO_Águas_Claras
#  + X_Hospital_Regional_de_Taguatinga_to_UNIEURO_Águas_Claras
#  + X_Hospital_Regional_do_Gama_to_UNIEURO_Águas_Claras
#  + X_Hospital_Regional_do_Paranoá_to_UNIEURO_Águas_Claras
#  + X_UBS_1___Núcleo_Bandeirante_to_UNIEURO_Águas_Claras = 1
#
# _C29: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Taguatinga
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_Taguatinga
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_Taguatinga
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_Taguatinga
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_Taguatinga
#  + X_Hospital_Regional_do_Gama_to_UBS_1_Taguatinga
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_Taguatinga
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Taguatinga = 1
#
# _C30: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Taguatinga
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_Taguatinga
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_Taguatinga
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_Taguatinga
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_Taguatinga
#  + X_Hospital_Regional_do_Gama_to_UBS_2_Taguatinga
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_Taguatinga
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Taguatinga = 1
#
# _C31: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Taguatinga
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_5_Taguatinga
#  + X_Hospital_Regional_de_Planaltina_to_UBS_5_Taguatinga
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_5_Taguatinga
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_5_Taguatinga
#  + X_Hospital_Regional_do_Gama_to_UBS_5_Taguatinga
#  + X_Hospital_Regional_do_Paranoá_to_UBS_5_Taguatinga
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Taguatinga = 1
#
# _C32: X_Hospital_Regional_da_Asa_Norte_to_UBS_7_Taguatinga
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_7_Taguatinga
#  + X_Hospital_Regional_de_Planaltina_to_UBS_7_Taguatinga
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_7_Taguatinga
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_7_Taguatinga
#  + X_Hospital_Regional_do_Gama_to_UBS_7_Taguatinga
#  + X_Hospital_Regional_do_Paranoá_to_UBS_7_Taguatinga
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_7_Taguatinga = 1
#
# _C33: X_Hospital_Regional_da_Asa_Norte_to_UBS_8_Taguatinga_
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_8_Taguatinga_
#  + X_Hospital_Regional_de_Planaltina_to_UBS_8_Taguatinga_
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_8_Taguatinga_
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_8_Taguatinga_
#  + X_Hospital_Regional_do_Gama_to_UBS_8_Taguatinga_
#  + X_Hospital_Regional_do_Paranoá_to_UBS_8_Taguatinga_
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_8_Taguatinga_ = 1
#
# _C34: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Samambaia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_Samambaia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_Samambaia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_Samambaia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_Samambaia
#  + X_Hospital_Regional_do_Gama_to_UBS_2_Samambaia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_Samambaia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Samambaia = 1
#
# _C35: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Samambaia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_5_Samambaia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_5_Samambaia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_5_Samambaia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_5_Samambaia
#  + X_Hospital_Regional_do_Gama_to_UBS_5_Samambaia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_5_Samambaia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Samambaia = 1
#
# _C36: X_Hospital_Regional_da_Asa_Norte_to_UBS_7_Samambaia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_7_Samambaia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_7_Samambaia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_7_Samambaia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_7_Samambaia
#  + X_Hospital_Regional_do_Gama_to_UBS_7_Samambaia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_7_Samambaia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_7_Samambaia = 1
#
# _C37: X_Hospital_Regional_da_Asa_Norte_to_UBS_11_Samambaia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_11_Samambaia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_11_Samambaia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_11_Samambaia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_11_Samambaia
#  + X_Hospital_Regional_do_Gama_to_UBS_11_Samambaia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_11_Samambaia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_11_Samambaia = 1
#
# _C38: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Recanto_das_Emas
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_3_Recanto_das_Emas
#  + X_Hospital_Regional_de_Planaltina_to_UBS_3_Recanto_das_Emas
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_3_Recanto_das_Emas
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_3_Recanto_das_Emas
#  + X_Hospital_Regional_do_Gama_to_UBS_3_Recanto_das_Emas
#  + X_Hospital_Regional_do_Paranoá_to_UBS_3_Recanto_das_Emas
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Recanto_das_Emas = 1
#
# _C39: X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Recanto_das_Emas
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_4_Recanto_das_Emas
#  + X_Hospital_Regional_de_Planaltina_to_UBS_4_Recanto_das_Emas
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_4_Recanto_das_Emas
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_4_Recanto_das_Emas
#  + X_Hospital_Regional_do_Gama_to_UBS_4_Recanto_das_Emas
#  + X_Hospital_Regional_do_Paranoá_to_UBS_4_Recanto_das_Emas
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_4_Recanto_das_Emas = 1
#
# _C40: X_Hospital_Regional_da_Asa_Norte_to_UBS_8_Recanto_das_Emas
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_8_Recanto_das_Emas
#  + X_Hospital_Regional_de_Planaltina_to_UBS_8_Recanto_das_Emas
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_8_Recanto_das_Emas
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_8_Recanto_das_Emas
#  + X_Hospital_Regional_do_Gama_to_UBS_8_Recanto_das_Emas
#  + X_Hospital_Regional_do_Paranoá_to_UBS_8_Recanto_das_Emas
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_8_Recanto_das_Emas = 1
#
# _C41: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Vicente_Pires
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_Vicente_Pires
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_Vicente_Pires
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_Vicente_Pires
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_Vicente_Pires
#  + X_Hospital_Regional_do_Gama_to_UBS_1_Vicente_Pires
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_Vicente_Pires
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Vicente_Pires = 1
#
# _C42: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Guará
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Guará
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Guará
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Guará
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Guará
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Guará
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Guará
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Guará = 1
#
# _C43: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_do_Guará
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_do_Guará
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_do_Guará
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_do_Guará
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_do_Guará
#  + X_Hospital_Regional_do_Gama_to_UBS_2_do_Guará
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_do_Guará
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_do_Guará = 1
#
# _C44: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_do_Guará
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_3_do_Guará
#  + X_Hospital_Regional_de_Planaltina_to_UBS_3_do_Guará
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_3_do_Guará
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_3_do_Guará
#  + X_Hospital_Regional_do_Gama_to_UBS_3_do_Guará
#  + X_Hospital_Regional_do_Paranoá_to_UBS_3_do_Guará
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_3_do_Guará = 1
#
# _C45: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Estrutural
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_da_Estrutural
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_da_Estrutural
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_da_Estrutural
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_da_Estrutural
#  + X_Hospital_Regional_do_Gama_to_UBS_1_da_Estrutural
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Estrutural
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Estrutural = 1
#
# _C46: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Estrutural
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_2_da_Estrutural
#  + X_Hospital_Regional_de_Planaltina_to_UBS_2_da_Estrutural
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_2_da_Estrutural
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_2_da_Estrutural
#  + X_Hospital_Regional_do_Gama_to_UBS_2_da_Estrutural
#  + X_Hospital_Regional_do_Paranoá_to_UBS_2_da_Estrutural
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_2_da_Estrutural = 1
#
# _C47: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Candangolândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_da_Candangolândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_da_Candangolândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_da_Candangolândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_da_Candangolândia
#  + X_Hospital_Regional_do_Gama_to_UBS_1_da_Candangolândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Candangolândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Candangolândia = 1
#
# _C48: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Núcleo_Bandeirante
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Núcleo_Bandeirante
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Núcleo_Bandeirante
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Núcleo_Bandeirante
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Núcleo_Bandeirante
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Núcleo_Bandeirante
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Núcleo_Bandeirante
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Núcleo_Bandeirante = 1
#
# _C49: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Riacho_Fundo_I
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Riacho_Fundo_I
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Riacho_Fundo_I
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Riacho_Fundo_I
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Riacho_Fundo_I
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Riacho_Fundo_I
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Riacho_Fundo_I
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Riacho_Fundo_I = 1
#
# _C50: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Riacho_Fundo_II
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Riacho_Fundo_II
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Riacho_Fundo_II
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Riacho_Fundo_II
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Riacho_Fundo_II
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Riacho_Fundo_II
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Riacho_Fundo_II
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Riacho_Fundo_II = 1
#
# _C51: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Jardins_Mangueiral
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Jardins_Mangueiral
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_do_Jardins_Mangueiral
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_do_Jardins_Mangueiral
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_do_Jardins_Mangueiral
#  + X_Hospital_Regional_do_Gama_to_UBS_1_do_Jardins_Mangueiral
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Jardins_Mangueiral
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Jardins_Mangueiral = 1
#
# _C52: X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Direitos___Itapoã
#  + X_Hospital_Regional_da_Ceilândia_to_Praça_dos_Direitos___Itapoã
#  + X_Hospital_Regional_de_Planaltina_to_Praça_dos_Direitos___Itapoã
#  + X_Hospital_Regional_de_Sobradinho_to_Praça_dos_Direitos___Itapoã
#  + X_Hospital_Regional_de_Taguatinga_to_Praça_dos_Direitos___Itapoã
#  + X_Hospital_Regional_do_Gama_to_Praça_dos_Direitos___Itapoã
#  + X_Hospital_Regional_do_Paranoá_to_Praça_dos_Direitos___Itapoã
#  + X_UBS_1___Núcleo_Bandeirante_to_Praça_dos_Direitos___Itapoã = 1
#
# _C53:
#  X_Hospital_Regional_da_Asa_Norte_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_Hospital_Regional_da_Ceilândia_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_Hospital_Regional_de_Planaltina_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_Hospital_Regional_de_Sobradinho_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_Hospital_Regional_de_Taguatinga_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_Hospital_Regional_do_Gama_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_Hospital_Regional_do_Paranoá_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  + X_UBS_1___Núcleo_Bandeirante_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  = 1
#
# _C54:
#  X_Hospital_Regional_da_Asa_Norte_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_Hospital_Regional_da_Ceilândia_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_Hospital_Regional_de_Planaltina_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_Hospital_Regional_de_Sobradinho_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_Hospital_Regional_de_Taguatinga_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_Hospital_Regional_do_Gama_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_Hospital_Regional_do_Paranoá_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  + X_UBS_1___Núcleo_Bandeirante_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  = 1
#
# _C55: X_Hospital_Regional_da_Asa_Norte_to_Shopping_Iguatemi
#  + X_Hospital_Regional_da_Ceilândia_to_Shopping_Iguatemi
#  + X_Hospital_Regional_de_Planaltina_to_Shopping_Iguatemi
#  + X_Hospital_Regional_de_Sobradinho_to_Shopping_Iguatemi
#  + X_Hospital_Regional_de_Taguatinga_to_Shopping_Iguatemi
#  + X_Hospital_Regional_do_Gama_to_Shopping_Iguatemi
#  + X_Hospital_Regional_do_Paranoá_to_Shopping_Iguatemi
#  + X_UBS_1___Núcleo_Bandeirante_to_Shopping_Iguatemi = 1
#
# _C56:
#  X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_Hospital_Regional_da_Ceilândia_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_Hospital_Regional_de_Planaltina_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_Hospital_Regional_de_Sobradinho_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_Hospital_Regional_de_Taguatinga_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_Hospital_Regional_do_Gama_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_Hospital_Regional_do_Paranoá_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  + X_UBS_1___Núcleo_Bandeirante_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  = 1
#
# _C57: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_1_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_de_Ceilândia = 1
#
# _C58: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_3_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_3_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_3_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_3_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_3_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_3_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_3_de_Ceilândia = 1
#
# _C59: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_5_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_5_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_5_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_5_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_5_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_5_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_5_de_Ceilândia = 1
#
# _C60: X_Hospital_Regional_da_Asa_Norte_to_UBS_6_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_6_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_6_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_6_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_6_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_6_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_6_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_6_de_Ceilândia = 1
#
# _C61: X_Hospital_Regional_da_Asa_Norte_to_UBS_7_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_7_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_7_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_7_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_7_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_7_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_7_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_7_de_Ceilândia = 1
#
# _C62: X_Hospital_Regional_da_Asa_Norte_to_UBS_10_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_10_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_10_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_10_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_10_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_10_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_10_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_10_de_Ceilândia = 1
#
# _C63: X_Hospital_Regional_da_Asa_Norte_to_UBS_11_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_11_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_11_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_11_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_11_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_11_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_11_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_11_de_Ceilândia = 1
#
# _C64: X_Hospital_Regional_da_Asa_Norte_to_UBS_12_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_12_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_12_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_12_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_12_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_12_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_12_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_12_de_Ceilândia = 1
#
# _C65: X_Hospital_Regional_da_Asa_Norte_to_UBS_16_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_16_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_16_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_16_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_16_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_16_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_16_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_16_de_Ceilândia = 1
#
# _C66: X_Hospital_Regional_da_Asa_Norte_to_UBS_17_de_Ceilândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_17_de_Ceilândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_17_de_Ceilândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_17_de_Ceilândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_17_de_Ceilândia
#  + X_Hospital_Regional_do_Gama_to_UBS_17_de_Ceilândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_17_de_Ceilândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_17_de_Ceilândia = 1
#
# _C67: X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Direitos_(Ceilândia)
#  + X_Hospital_Regional_da_Ceilândia_to_Praça_dos_Direitos_(Ceilândia)
#  + X_Hospital_Regional_de_Planaltina_to_Praça_dos_Direitos_(Ceilândia)
#  + X_Hospital_Regional_de_Sobradinho_to_Praça_dos_Direitos_(Ceilândia)
#  + X_Hospital_Regional_de_Taguatinga_to_Praça_dos_Direitos_(Ceilândia)
#  + X_Hospital_Regional_do_Gama_to_Praça_dos_Direitos_(Ceilândia)
#  + X_Hospital_Regional_do_Paranoá_to_Praça_dos_Direitos_(Ceilândia)
#  + X_UBS_1___Núcleo_Bandeirante_to_Praça_dos_Direitos_(Ceilândia) = 1
#
# _C68: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_de_Brazlândia
#  + X_Hospital_Regional_da_Ceilândia_to_UBS_1_de_Brazlândia
#  + X_Hospital_Regional_de_Planaltina_to_UBS_1_de_Brazlândia
#  + X_Hospital_Regional_de_Sobradinho_to_UBS_1_de_Brazlândia
#  + X_Hospital_Regional_de_Taguatinga_to_UBS_1_de_Brazlândia
#  + X_Hospital_Regional_do_Gama_to_UBS_1_de_Brazlândia
#  + X_Hospital_Regional_do_Paranoá_to_UBS_1_de_Brazlândia
#  + X_UBS_1___Núcleo_Bandeirante_to_UBS_1_de_Brazlândia = 1
#
# _C69: Y_Hospital_Regional_da_Asa_Norte + Y_Hospital_Regional_da_Ceilândia
#  + Y_Hospital_Regional_de_Planaltina + Y_Hospital_Regional_de_Sobradinho
#  + Y_Hospital_Regional_de_Taguatinga + Y_Hospital_Regional_do_Gama
#  + Y_Hospital_Regional_do_Paranoá + Y_UBS_1___Núcleo_Bandeirante = 8
#
# _C70: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Lago_Norte
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C71: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Varjão
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C72: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Norte
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C73: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Asa_Norte
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C74: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Sul
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C75: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Cruzeiro
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C76: X_Hospital_Regional_da_Asa_Norte_to_Parque_da_Cidade___Estacionamento_13
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C77: X_Hospital_Regional_da_Asa_Norte_to_Associação_Médica_de_Brasília_(Ambr)
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C78: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Vila_Planalto_
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C79: X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Cristais
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C80: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Sobradinho
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C81: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Sobradinho
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C82: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Sobradinho_II
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C83: X_Hospital_Regional_da_Asa_Norte_to_Regional_de_Ensino_Sobradinho_II
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C84: X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Planaltina
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C85: X_Hospital_Regional_da_Asa_Norte_to_Centro_Olímpico_de_Planaltina
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C86: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Planaltina
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C87: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Planaltina
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C88: X_Hospital_Regional_da_Asa_Norte_to_SESI_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C89: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C90: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C91: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C92: X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C93: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C94: X_Hospital_Regional_da_Asa_Norte_to_UBS_6_Gama
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C95: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Santa_Maria
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C96: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Santa_Maria
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C97: X_Hospital_Regional_da_Asa_Norte_to_UNIEURO_Águas_Claras
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C98: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Taguatinga
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C99: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Taguatinga
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C100: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Taguatinga
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C101: X_Hospital_Regional_da_Asa_Norte_to_UBS_7_Taguatinga
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C102: X_Hospital_Regional_da_Asa_Norte_to_UBS_8_Taguatinga_
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C103: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_Samambaia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C104: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_Samambaia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C105: X_Hospital_Regional_da_Asa_Norte_to_UBS_7_Samambaia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C106: X_Hospital_Regional_da_Asa_Norte_to_UBS_11_Samambaia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C107: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Recanto_das_Emas
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C108: X_Hospital_Regional_da_Asa_Norte_to_UBS_4_Recanto_das_Emas
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C109: X_Hospital_Regional_da_Asa_Norte_to_UBS_8_Recanto_das_Emas
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C110: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Vicente_Pires
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C111: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Guará
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C112: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_do_Guará
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C113: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_do_Guará
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C114: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Estrutural
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C115: X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Estrutural
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C116: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Candangolândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C117: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Núcleo_Bandeirante
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C118: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Riacho_Fundo_I
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C119: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Riacho_Fundo_II
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C120: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Jardins_Mangueiral
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C121: X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Direitos___Itapoã
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C122:
#  X_Hospital_Regional_da_Asa_Norte_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião)
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C123:
#  X_Hospital_Regional_da_Asa_Norte_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional)
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C124: X_Hospital_Regional_da_Asa_Norte_to_Shopping_Iguatemi
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C125:
#  X_Hospital_Regional_da_Asa_Norte_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C126: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C127: X_Hospital_Regional_da_Asa_Norte_to_UBS_3_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C128: X_Hospital_Regional_da_Asa_Norte_to_UBS_5_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C129: X_Hospital_Regional_da_Asa_Norte_to_UBS_6_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C130: X_Hospital_Regional_da_Asa_Norte_to_UBS_7_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C131: X_Hospital_Regional_da_Asa_Norte_to_UBS_10_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C132: X_Hospital_Regional_da_Asa_Norte_to_UBS_11_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C133: X_Hospital_Regional_da_Asa_Norte_to_UBS_12_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C134: X_Hospital_Regional_da_Asa_Norte_to_UBS_16_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C135: X_Hospital_Regional_da_Asa_Norte_to_UBS_17_de_Ceilândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C136: X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Direitos_(Ceilândia)
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C137: X_Hospital_Regional_da_Asa_Norte_to_UBS_1_de_Brazlândia
#  - Y_Hospital_Regional_da_Asa_Norte <= 0
#
# _C138: X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Lago_Norte
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C139: X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Varjão
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C140: X_Hospital_Regional_da_Ceilândia_to_UBS_1_da_Asa_Norte
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C141: X_Hospital_Regional_da_Ceilândia_to_UBS_2_da_Asa_Norte
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C142: X_Hospital_Regional_da_Ceilândia_to_UBS_1_da_Asa_Sul
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C143: X_Hospital_Regional_da_Ceilândia_to_UBS_1_do_Cruzeiro
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C144:
#  X_Hospital_Regional_da_Ceilândia_to_Parque_da_Cidade___Estacionamento_13
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C145:
#  X_Hospital_Regional_da_Ceilândia_to_Associação_Médica_de_Brasília_(Ambr)
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C146: X_Hospital_Regional_da_Ceilândia_to_UBS_3_Vila_Planalto_
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C147: X_Hospital_Regional_da_Ceilândia_to_Praça_dos_Cristais
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C148: X_Hospital_Regional_da_Ceilândia_to_UBS_1_Sobradinho
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C149: X_Hospital_Regional_da_Ceilândia_to_UBS_3_Sobradinho
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C150: X_Hospital_Regional_da_Ceilândia_to_UBS_1_Sobradinho_II
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C151: X_Hospital_Regional_da_Ceilândia_to_Regional_de_Ensino_Sobradinho_II
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C152: X_Hospital_Regional_da_Ceilândia_to_UBS_4_Planaltina
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C153: X_Hospital_Regional_da_Ceilândia_to_Centro_Olímpico_de_Planaltina
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C154: X_Hospital_Regional_da_Ceilândia_to_UBS_2_Planaltina
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C155: X_Hospital_Regional_da_Ceilândia_to_UBS_5_Planaltina
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C156: X_Hospital_Regional_da_Ceilândia_to_SESI_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C157: X_Hospital_Regional_da_Ceilândia_to_UBS_1_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C158: X_Hospital_Regional_da_Ceilândia_to_UBS_2_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C159: X_Hospital_Regional_da_Ceilândia_to_UBS_3_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C160: X_Hospital_Regional_da_Ceilândia_to_UBS_4_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C161: X_Hospital_Regional_da_Ceilândia_to_UBS_5_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C162: X_Hospital_Regional_da_Ceilândia_to_UBS_6_Gama
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C163: X_Hospital_Regional_da_Ceilândia_to_UBS_1_Santa_Maria
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C164: X_Hospital_Regional_da_Ceilândia_to_UBS_2_Santa_Maria
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C165: X_Hospital_Regional_da_Ceilândia_to_UNIEURO_Águas_Claras
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C166: X_Hospital_Regional_da_Ceilândia_to_UBS_1_Taguatinga
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C167: X_Hospital_Regional_da_Ceilândia_to_UBS_2_Taguatinga
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C168: X_Hospital_Regional_da_Ceilândia_to_UBS_5_Taguatinga
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C169: X_Hospital_Regional_da_Ceilândia_to_UBS_7_Taguatinga
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C170: X_Hospital_Regional_da_Ceilândia_to_UBS_8_Taguatinga_
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C171: X_Hospital_Regional_da_Ceilândia_to_UBS_2_Samambaia
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C172: X_Hospital_Regional_da_Ceilândia_to_UBS_5_Samambaia
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C173: X_Hospital_Regional_da_Ceilândia_to_UBS_7_Samambaia
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# _C174: X_Hospital_Regional_da_Ceilândia_to_UBS_11_Samambaia
#  - Y_Hospital_Regional_da_Ceilândia <= 0
#
# ...
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_4_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_5_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_5_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_5_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_5_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_5_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_6_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_6_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_7_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_7_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_7_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_8_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UBS_8_Taguatinga_ <= 1 Integer
# 0 <= X_Hospital_Regional_de_Taguatinga_to_UNIEURO_Águas_Claras <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Associação_Médica_de_Brasília_(Ambr) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Centro_Olímpico_de_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Parque_da_Cidade___Estacionamento_13 <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Praça_dos_Cristais <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Praça_dos_Direitos_(Ceilândia) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Praça_dos_Direitos___Itapoã <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Regional_de_Ensino_Sobradinho_II <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_SESI_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_Shopping_Iguatemi <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_10_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_11_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_11_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_12_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_16_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_17_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_Santa_Maria <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_Sobradinho <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_Sobradinho_II <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_Vicente_Pires <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_da_Asa_Norte <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_da_Asa_Sul <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_da_Candangolândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_da_Estrutural <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_de_Brazlândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Cruzeiro <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Guará <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Jardins_Mangueiral <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Lago_Norte <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Núcleo_Bandeirante <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Riacho_Fundo_I <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Riacho_Fundo_II <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_1_do_Varjão <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_Santa_Maria <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_da_Asa_Norte <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_da_Estrutural <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_2_do_Guará <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_3_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_3_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_3_Sobradinho <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_3_Vila_Planalto_ <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_3_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_3_do_Guará <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_4_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_4_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_4_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_5_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_5_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_5_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_5_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_5_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_6_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_6_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_7_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_7_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_7_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_8_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UBS_8_Taguatinga_ <= 1 Integer
# 0 <= X_Hospital_Regional_do_Gama_to_UNIEURO_Águas_Claras <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Associação_Médica_de_Brasília_(Ambr) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Centro_Olímpico_de_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Parque_da_Cidade___Estacionamento_13 <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Praça_dos_Cristais <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Praça_dos_Direitos_(Ceilândia) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Praça_dos_Direitos___Itapoã <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional) <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Regional_de_Ensino_Sobradinho_II <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_SESI_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_Shopping_Iguatemi <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_10_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_11_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_11_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_12_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_16_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_17_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_Santa_Maria <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_Sobradinho <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_Sobradinho_II <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_Vicente_Pires <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Asa_Norte <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Asa_Sul <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Candangolândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_da_Estrutural <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_de_Brazlândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Cruzeiro <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Guará <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Jardins_Mangueiral <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Lago_Norte <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Núcleo_Bandeirante <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Riacho_Fundo_I <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Riacho_Fundo_II <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Varjão <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_Santa_Maria <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_da_Asa_Norte <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_da_Estrutural <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_2_do_Guará <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_3_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_3_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_3_Sobradinho <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_3_Vila_Planalto_ <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_3_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_3_do_Guará <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_4_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_4_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_4_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_5_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_5_Planaltina <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_5_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_5_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_5_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_6_Gama <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_6_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_7_Samambaia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_7_Taguatinga <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_7_de_Ceilândia <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_8_Recanto_das_Emas <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UBS_8_Taguatinga_ <= 1 Integer
# 0 <= X_Hospital_Regional_do_Paranoá_to_UNIEURO_Águas_Claras <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Associação_Médica_de_Brasília_(Ambr) <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Centro_Olímpico_de_Planaltina <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião) <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Parque_da_Cidade___Estacionamento_13 <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Praça_dos_Cristais <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Praça_dos_Direitos_(Ceilândia) <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Praça_dos_Direitos___Itapoã <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional) <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Regional_de_Ensino_Sobradinho_II <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_SESI_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_Shopping_Iguatemi <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_10_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_11_Samambaia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_11_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_12_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_16_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_17_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Santa_Maria <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Sobradinho <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Sobradinho_II <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Taguatinga <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_Vicente_Pires <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Asa_Norte <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Asa_Sul <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Candangolândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Estrutural <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_de_Brazlândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Cruzeiro <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Guará <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Jardins_Mangueiral <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Lago_Norte <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Núcleo_Bandeirante <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Riacho_Fundo_I <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Riacho_Fundo_II <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Varjão <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Planaltina <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Samambaia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Santa_Maria <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_Taguatinga <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_da_Asa_Norte <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_da_Estrutural <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_2_do_Guará <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Recanto_das_Emas <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Sobradinho <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_3_Vila_Planalto_ <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_3_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_3_do_Guará <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_4_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_4_Planaltina <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_4_Recanto_das_Emas <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Planaltina <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Samambaia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_5_Taguatinga <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_5_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_6_Gama <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_6_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_7_Samambaia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_7_Taguatinga <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_7_de_Ceilândia <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_8_Recanto_das_Emas <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UBS_8_Taguatinga_ <= 1 Integer
# 0 <= X_UBS_1___Núcleo_Bandeirante_to_UNIEURO_Águas_Claras <= 1 Integer
# 0 <= Y_Hospital_Regional_da_Asa_Norte <= 1 Integer
# 0 <= Y_Hospital_Regional_da_Ceilândia <= 1 Integer
# 0 <= Y_Hospital_Regional_de_Planaltina <= 1 Integer
# 0 <= Y_Hospital_Regional_de_Sobradinho <= 1 Integer
# 0 <= Y_Hospital_Regional_de_Taguatinga <= 1 Integer
# 0 <= Y_Hospital_Regional_do_Gama <= 1 Integer
# 0 <= Y_Hospital_Regional_do_Paranoá <= 1 Integer
# 0 <= Y_UBS_1___Núcleo_Bandeirante <= 1 Integer

# %%
prob.solve()
# Out:
# 1

# %%
print(f'Total: {prob.objective.value()/1000} Km')
# Out:
# Total: 530.14 Km

# %%
for v in prob.variables():
    #print(v.name , '=', v.varValue)
    if v.varValue == 1:
        print(v.name , '=', v.varValue)
# Out:
# X_Hospital_Regional_da_Asa_Norte_to_Associação_Médica_de_Brasília_(Ambr) = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_Parque_da_Cidade___Estacionamento_13 = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_Praça_dos_Cristais = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_Shopping_Iguatemi = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_1_Santa_Maria = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Norte = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_1_da_Asa_Sul = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Lago_Norte = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_1_do_Varjão = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_2_da_Asa_Norte = 1.0
# X_Hospital_Regional_da_Asa_Norte_to_UBS_3_Vila_Planalto_ = 1.0
# X_Hospital_Regional_da_Ceilândia_to_Praça_dos_Direitos_(Ceilândia) = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_10_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_11_Samambaia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_11_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_12_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_16_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_1_de_Brazlândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_1_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_3_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_4_Recanto_das_Emas = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_5_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_7_Taguatinga = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_7_de_Ceilândia = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_8_Recanto_das_Emas = 1.0
# X_Hospital_Regional_da_Ceilândia_to_UBS_8_Taguatinga_ = 1.0
# X_Hospital_Regional_de_Planaltina_to_Centro_Olímpico_de_Planaltina = 1.0
# X_Hospital_Regional_de_Planaltina_to_UBS_2_Planaltina = 1.0
# X_Hospital_Regional_de_Planaltina_to_UBS_4_Planaltina = 1.0
# X_Hospital_Regional_de_Planaltina_to_UBS_5_Planaltina = 1.0
# X_Hospital_Regional_de_Sobradinho_to_Regional_de_Ensino_Sobradinho_II = 1.0
# X_Hospital_Regional_de_Sobradinho_to_UBS_1_Sobradinho = 1.0
# X_Hospital_Regional_de_Sobradinho_to_UBS_1_Sobradinho_II = 1.0
# X_Hospital_Regional_de_Sobradinho_to_UBS_3_Sobradinho = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_17_de_Ceilândia = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_1_Taguatinga = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_1_Vicente_Pires = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_1_da_Estrutural = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_2_Samambaia = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_2_Taguatinga = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_2_da_Estrutural = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_3_Recanto_das_Emas = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_5_Samambaia = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_5_Taguatinga = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_6_de_Ceilândia = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UBS_7_Samambaia = 1.0
# X_Hospital_Regional_de_Taguatinga_to_UNIEURO_Águas_Claras = 1.0
# X_Hospital_Regional_do_Gama_to_SESI_Gama = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_1_Gama = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_1_do_Riacho_Fundo_II = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_2_Gama = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_2_Santa_Maria = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_3_Gama = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_4_Gama = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_5_Gama = 1.0
# X_Hospital_Regional_do_Gama_to_UBS_6_Gama = 1.0
# X_Hospital_Regional_do_Paranoá_to_Centro_de_Práticas_Sustentáveis_do_Jardim_Botânico = 1.0
# X_Hospital_Regional_do_Paranoá_to_Ginásio_Poliesportivo_São_Bartolomeu_(São_Sebastião) = 1.0
# X_Hospital_Regional_do_Paranoá_to_Praça_dos_Direitos___Itapoã = 1.0
# X_Hospital_Regional_do_Paranoá_to_Quadra_coberta_do_Paranoá_(ao_lado_da_adm._Regional) = 1.0
# X_Hospital_Regional_do_Paranoá_to_UBS_1_do_Jardins_Mangueiral = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_1_da_Candangolândia = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Cruzeiro = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Guará = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Núcleo_Bandeirante = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_1_do_Riacho_Fundo_I = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_2_do_Guará = 1.0
# X_UBS_1___Núcleo_Bandeirante_to_UBS_3_do_Guará = 1.0
# Y_Hospital_Regional_da_Asa_Norte = 1.0
# Y_Hospital_Regional_da_Ceilândia = 1.0
# Y_Hospital_Regional_de_Planaltina = 1.0
# Y_Hospital_Regional_de_Sobradinho = 1.0
# Y_Hospital_Regional_de_Taguatinga = 1.0
# Y_Hospital_Regional_do_Gama = 1.0
# Y_Hospital_Regional_do_Paranoá = 1.0
# Y_UBS_1___Núcleo_Bandeirante = 1.0

# %%
df = pd.DataFrame(columns=['origem', 'destino'])
for v in prob.variables():
    #print(v.name , '=', v.varValue)
    if v.varValue == 1:
        #print(v.name , '=', v.varValue)
        split = v.name.split('_to_')
        split[0] = split[0].replace('X_', '')
        try:
            df = df.append({'origem': split[0], 'destino': split[1]}, ignore_index=True)
        except:
            pass

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_6d497_ thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_6d497_ tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_6d497_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >origem</th>
#       <th class="col_heading level0 col1" >destino</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d497_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d497_row0_col0" class="data row0 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row0_col1" class="data row0 col1" >Associação_Médica_de_Brasília_(Ambr)</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d497_row1_col0" class="data row1 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row1_col1" class="data row1 col1" >Parque_da_Cidade___Estacionamento_13</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d497_row2_col0" class="data row2 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row2_col1" class="data row2 col1" >Praça_dos_Cristais</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d497_row3_col0" class="data row3 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row3_col1" class="data row3 col1" >Shopping_Iguatemi</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d497_row4_col0" class="data row4 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row4_col1" class="data row4 col1" >UBS_1_Santa_Maria</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d497_row5_col0" class="data row5 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row5_col1" class="data row5 col1" >UBS_1_da_Asa_Norte</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d497_row6_col0" class="data row6 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row6_col1" class="data row6 col1" >UBS_1_da_Asa_Sul</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d497_row7_col0" class="data row7 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row7_col1" class="data row7 col1" >UBS_1_do_Lago_Norte</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d497_row8_col0" class="data row8 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row8_col1" class="data row8 col1" >UBS_1_do_Varjão</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d497_row9_col0" class="data row9 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row9_col1" class="data row9 col1" >UBS_2_da_Asa_Norte</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6d497_row10_col0" class="data row10 col0" >Hospital_Regional_da_Asa_Norte</td>
#       <td id="T_6d497_row10_col1" class="data row10 col1" >UBS_3_Vila_Planalto_</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6d497_row11_col0" class="data row11 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row11_col1" class="data row11 col1" >Praça_dos_Direitos_(Ceilândia)</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6d497_row12_col0" class="data row12 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row12_col1" class="data row12 col1" >UBS_10_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6d497_row13_col0" class="data row13 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row13_col1" class="data row13 col1" >UBS_11_Samambaia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6d497_row14_col0" class="data row14 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row14_col1" class="data row14 col1" >UBS_11_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6d497_row15_col0" class="data row15 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row15_col1" class="data row15 col1" >UBS_12_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6d497_row16_col0" class="data row16 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row16_col1" class="data row16 col1" >UBS_16_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6d497_row17_col0" class="data row17 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row17_col1" class="data row17 col1" >UBS_1_de_Brazlândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6d497_row18_col0" class="data row18 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row18_col1" class="data row18 col1" >UBS_1_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6d497_row19_col0" class="data row19 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row19_col1" class="data row19 col1" >UBS_3_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6d497_row20_col0" class="data row20 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row20_col1" class="data row20 col1" >UBS_4_Recanto_das_Emas</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6d497_row21_col0" class="data row21 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row21_col1" class="data row21 col1" >UBS_5_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_6d497_row22_col0" class="data row22 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row22_col1" class="data row22 col1" >UBS_7_Taguatinga</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_6d497_row23_col0" class="data row23 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row23_col1" class="data row23 col1" >UBS_7_de_Ceilândia</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_6d497_row24_col0" class="data row24 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row24_col1" class="data row24 col1" >UBS_8_Recanto_das_Emas</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_6d497_row25_col0" class="data row25 col0" >Hospital_Regional_da_Ceilândia</td>
#       <td id="T_6d497_row25_col1" class="data row25 col1" >UBS_8_Taguatinga_</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_6d497_row26_col0" class="data row26 col0" >Hospital_Regional_de_Planaltina</td>
#       <td id="T_6d497_row26_col1" class="data row26 col1" >Centro_Olímpico_de_Planaltina</td>
#     </tr>
#     <tr>
#       <th id="T_6d497_level0_row27" class="row_heading level0 row27" >27</t

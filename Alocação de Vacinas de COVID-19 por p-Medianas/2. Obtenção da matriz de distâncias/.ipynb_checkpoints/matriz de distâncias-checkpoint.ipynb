# %%
from pulp import *
import googlemaps
import pandas as pd
import time

# %%
client = googlemaps.Client(key = 'AIzaSyBU3xNODle9W35YxeAhWsX4P6C0fsxcopY')

# %%
unidades = list(unidades['Google Maps'])

# %%
centros = pd.read_csv('centros.csv')
centros = list(centros['centros'])

# %%
df = pd.DataFrame(columns = centros)

# %%
df
# Out:
#                                                    Hospital Regional da Asa Norte  \
# Unidade Básica de Saúde 1 Águas Claras                                      24596
# UBS 2 - Areal                                                               24914
# SAP 01 da Asa Norte                                                          2471
# Unidade Básica de Saúde (UBS) 2 Asa Norte                                    6566
# Unidade Básica de Saúde (UBS) 3 - Asa Norte - V...                           8557
# ...                                                                           ...
# Praça dos Direitos (Ceilândia)                                              31629
# Quadra coberta do Paranoá (ao lado da adm. Regi...                          24342
# Regional de Ensino Sobradinho II                                            25799
# UNIEURO Águas Claras                                                         7940
# ...

# %%
for j in centros:
    for i in unidades:
        try:
            df.at[i,j] = client.distance_matrix(origins=j,destinations=i, mode='driving')['rows'][0]['elements'][0]['distance']['value']
        except:
            print(i, j)
# Out:
# UBS 01 Cruzeiro Novo (GSAP) Hospital Regional da Asa Norte
# Unidade Básica de Saúde (UBS) 2 Cruzeiro Hospital Regional da Asa Norte
# UBS Catingueiro Hospital Regional da Asa Norte
# UBS 8 - Gama Hospital Regional da Asa Norte
# UBS 09 - Gama Hospital Regional da Asa Norte
# UNIDADE BÁSICA DE SAÚDE N° 11 GAMA Hospital Regional da Asa Norte
# Unidade Básica de Saúde Ponte Alta de Cima. Hospital Regional da Asa Norte
# UBS 15 Gama PFDF Hospital Regional da Asa Norte
# UBS 16 Gama - ATP - Ala de Tratamento Psiquiátrico Hospital Regional da Asa Norte
# Centro de Saúde Guará - 01 Hospital Regional da Asa Norte
# UBS Rajadinha Hospital Regional da Asa Norte
# UBS 13 Norte Hospital Regional da Asa Norte
# Posto de Saúde CAIC Hospital Regional da Asa Norte
# ESF 02 UBS 8 REC Hospital Regional da Asa Norte
# UBS 03 - Santa Maria Hospital Regional da Asa Norte
# UBS 06 - Santa Maria Hospital Regional da Asa Norte
# Ubs 7 de Santa Maria Hospital Regional da Asa Norte
# ...

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_9992a_ thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_9992a_ tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_9992a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Hospital Regional da Asa Norte</th>
#       <th class="col_heading level0 col1" >Hospital Regional da Ceilândia</th>
#       <th class="col_heading level0 col2" >Hospital Regional do Gama</th>
#       <th class="col_heading level0 col3" >Hospital Regional do Paranoá</th>
#       <th class="col_heading level0 col4" >Hospital Regional de Planaltina</th>
#       <th class="col_heading level0 col5" >Hospital Regional de Taguatinga</th>
#       <th class="col_heading level0 col6" >Hospital Regional de Sobradinho</th>
# ...

# %%
df.shape
# Out:
# (147, 8)

# %%
df.to_csv('matriz final new.csv')
